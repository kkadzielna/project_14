# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import missingno as msno
from collections import Counter
from itertools import chain, combinations
import sklearn as sk
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score, make_scorer

# %%
data = pd.read_csv("newdata3.csv", engine='python').drop(['Unnamed: 0'], axis = 1)

# %%
dep_data = data.copy()
dep_num = np.array([12, 11, 10, 4])
no_dep_num = np.setdiff1d(range(13), dep_num)

dep_data[['prim_diag', 'secd_diag']] = dep_data[['prim_diag', 'secd_diag']].replace(list(no_dep_num), 0)
dep_data[['prim_diag', 'secd_diag']] = dep_data[['prim_diag', 'secd_diag']].replace(list(dep_num), 1)


full = data.dropna(axis = 0, how = 'any')
dep = [x for x in data.columns if 'dep' in x or 'diag' in x or 'panic' in x]

# %%
dep_data['dep'] = dep_data['secd_diag'] + dep_data['prim_diag'] + 0 * dep_data['has_dep_diag']
dep_data['dep'] = dep_data['dep'].replace(range(2, 4), 1)

# %%
full = dep_data.dropna(axis = 0, how = 'any')
dep = [x for x in data.columns if 'dep' in x or 'diag' in x or 'panic' in x]

has_dep = full.query('dep == 1')
no_dep = full.query('dep == 0')
size = int(np.round(0.8 * min(len(has_dep), len(no_dep))))
sample = has_dep.sample(size).append(no_dep.sample(size))

sample = sample.sort_index()
sample = sample.reset_index(drop = True)

X = sample.drop(dep, axis = 1).drop('dep', axis = 1)
y = sample['dep']
# Out:
# C:\Users\moham\AppData\Local\Temp/ipykernel_27536/2304885161.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sample = has_dep.sample(size).append(no_dep.sample(size))

# %%
params = {'C': np.logspace(-5, 2, 7)}

def optimise(clf, params, X, y, verb):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    grid = GridSearchCV(clf, params, scoring = 'f1_micro', n_jobs = 1, verbose = verb)
    grid.fit(X, y)
    return grid

# %% [markdown]
# ## Model on normal data

# %%
clf = LogisticRegression(penalty = 'l2', max_iter = 1000)

grid = optimise(clf, params, X, y, 0)

# %%
def plot_grid_search(cv_results, grid_param_1, grid_param_2, name_param_1, name_param_2):
    # Get Test Scores Mean and std for each grid search
    scores_mean = cv_results['mean_test_score']
    scores_mean = np.array(scores_mean).reshape(len(grid_param_2),len(grid_param_1))

    scores_sd = cv_results['std_test_score']
    scores_sd = np.array(scores_sd).reshape(len(grid_param_2),len(grid_param_1))

    # Plot Grid search scores
    _, ax = plt.subplots(1,1)

    # Param1 is the X-axis, Param 2 is represented as a different curve (color line)
    for idx, val in enumerate(grid_param_2):
        ax.plot(grid_param_1, scores_mean[idx,:], '-o', label= name_param_2 + ': ' + str(val))

    ax.set_title("Grid Search Scores", fontsize=20, fontweight='bold')
    ax.set_xlabel(name_param_1, fontsize=16)
    ax.set_ylabel('CV Average Score', fontsize=16)
    ax.legend(loc="best", fontsize=15)
    ax.grid('on')

# %%
plot_grid_search(grid.cv_results_, params['C'], [1000], 'C', 'max_iter')

# %%
grid.best_score_
# Out:
# 0.5069549970777324

# %% [markdown]
# ## Model on PCA data

# %%
pca = PCA(2)
X_pca = pca.fit_transform(X)

per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)] 
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %%
plot = plt.scatter(X_pca[:,0], X_pca[:,1], c=y)
plt.legend(handles=plot.legend_elements()[0], labels=list(y.unique()))
plt.show()

# %%
clf = LogisticRegression(penalty = 'l2', max_iter = 1000)

grid = optimise(clf, params, X_pca, y, 0)
grid.best_score_
# Out:
# 0.5239625949736996

# %%
plot_grid_search(grid.cv_results_, params['C'], [1000], 'C', 'max_iter')

# %%
pca = PCA(3)
X_pca = pca.fit_transform(X)

per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)] 
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c = y)
plt.legend(handles=plot.legend_elements()[0], labels=list(y.unique()))
plt.show()

# %%
clf = LogisticRegression(penalty = 'l2', max_iter = 1000)

grid = optimise(clf, params, X_pca, y, 0)
grid.best_score_
# Out:
# 0.5239625949736996

# %%
plot_grid_search(grid.cv_results_, params['C'], [1000], 'C', 'max_iter')

# %% [markdown]
# ## Model on scaled PCA data

# %%
pca = PCA(0.9)
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
plt.figure(figsize=(8,6))
X_pca = pipe.fit_transform(X)

per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)] 
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %%
pca_df = pd.DataFrame(X_pca, index = X.index, columns = labels)
plot = plt.scatter(X_pca[:,0], X_pca[:,1], c=y)
legend = list(y.unique())
plt.legend(handles=plot.legend_elements()[0], labels=legend)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("First two principal components after scaling")
#for sample in pca_df.index:
#    plt.annotate(sample, (pca_df.PC1.loc[sample], pca_df.PC2.loc[sample]))
plt.show()

# %%
clf = LogisticRegression(penalty = 'l2', max_iter = 1000)

grid = optimise(clf, params, X_pca, y, 0)
grid.best_score_
# Out:
# 0.5135593220338983

# %%
plot_grid_search(grid.cv_results_, params['C'], [1000], 'C', 'max_iter')

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c = y)
plt.legend(handles=plot.legend_elements()[0], labels=list(y.unique()))
plt.show()

# %%
from sklearn import svm

svc = [svm.SVC(), {
        'C': [0.01,0.1,1,10,100],
        'kernel': ['rbf', 'sigmoid'],
        'gamma': [1,0.1,0.01,0.001]
        }]

# %%
grid = optimise(svc[0], svc[1], X, y, 10)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5; 1/40] START C=0.01, gamma=1, kernel=rbf................................
# [CV 1/5; 1/40] END .C=0.01, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 1/40] START C=0.01, gamma=1, kernel=rbf................................
# [CV 2/5; 1/40] END .C=0.01, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 1/40] START C=0.01, gamma=1, kernel=rbf................................
# [CV 3/5; 1/40] END .C=0.01, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 1/40] START C=0.01, gamma=1, kernel=rbf................................
# [CV 4/5; 1/40] END .C=0.01, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 1/40] START C=0.01, gamma=1, kernel=rbf................................
# [CV 5/5; 1/40] END .C=0.01, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5; 2/40] START C=0.01, gamma=1, kernel=sigmoid............................
# [CV 1/5; 2/40] END C=0.01, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 2/40] START C=0.01, gamma=1, kernel=sigmoid............................
# [CV 2/5; 2/40] END C=0.01, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 2/40] START C=0.01, gamma=1, kernel=sigmoid............................
# [CV 3/5; 2/40] END C=0.01, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 2/40] START C=0.01, gamma=1, kernel=sigmoid............................
# [CV 4/5; 2/40] END C=0.01, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 2/40] START C=0.01, gamma=1, kernel=sigmoid............................
# [CV 5/5; 2/40] END C=0.01, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 3/40] START C=0.01, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 3/40] END C=0.01, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 3/40] START C=0.01, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 3/40] END C=0.01, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 3/40] START C=0.01, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 3/40] END C=0.01, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 3/40] START C=0.01, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 3/40] END C=0.01, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 3/40] START C=0.01, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 3/40] END C=0.01, gamma=0.1, kernel=rbf;, score=0.483 total time=   0.0s
# [CV 1/5; 4/40] START C=0.01, gamma=0.1, kernel=sigmoid..........................
# [CV 1/5; 4/40] END C=0.01, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 4/40] START C=0.01, gamma=0.1, kernel=sigmoid..........................
# [CV 2/5; 4/40] END C=0.01, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 4/40] START C=0.01, gamma=0.1, kernel=sigmoid..........................
# [CV 3/5; 4/40] END C=0.01, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 4/40] START C=0.01, gamma=0.1, kernel=sigmoid..........................
# [CV 4/5; 4/40] END C=0.01, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 4/40] START C=0.01, gamma=0.1, kernel=sigmoid..........................
# [CV 5/5; 4/40] END C=0.01, gamma=0.1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 5/40] START C=0.01, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 5/40] END C=0.01, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 5/40] START C=0.01, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 5/40] END C=0.01, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 5/40] START C=0.01, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 5/40] END C=0.01, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 5/40] START C=0.01, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 5/40] END C=0.01, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 5/40] START C=0.01, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 5/40] END C=0.01, gamma=0.01, kernel=rbf;, score=0.534 total time=   0.0s
# [CV 1/5; 6/40] START C=0.01, gamma=0.01, kernel=sigmoid.........................
# [CV 1/5; 6/40] END C=0.01, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 6/40] START C=0.01, gamma=0.01, kernel=sigmoid.........................
# [CV 2/5; 6/40] END C=0.01, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 6/40] START C=0.01, gamma=0.01, kernel=sigmoid.........................
# [CV 3/5; 6/40] END C=0.01, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 6/40] START C=0.01, gamma=0.01, kernel=sigmoid.........................
# [CV 4/5; 6/40] END C=0.01, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 6/40] START C=0.01, gamma=0.01, kernel=sigmoid.........................
# [CV 5/5; 6/40] END C=0.01, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 7/40] START C=0.01, gamma=0.001, kernel=rbf............................
# [CV 1/5; 7/40] END C=0.01, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 7/40] START C=0.01, gamma=0.001, kernel=rbf............................
# [CV 2/5; 7/40] END C=0.01, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 7/40] START C=0.01, gamma=0.001, kernel=rbf............................
# [CV 3/5; 7/40] END C=0.01, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 7/40] START C=0.01, gamma=0.001, kernel=rbf............................
# [CV 4/5; 7/40] END C=0.01, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 7/40] START C=0.01, gamma=0.001, kernel=rbf............................
# [CV 5/5; 7/40] END C=0.01, gamma=0.001, kernel=rbf;, score=0.517 total time=   0.0s
# [CV 1/5; 8/40] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [CV 1/5; 8/40] END C=0.01, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 8/40] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [CV 2/5; 8/40] END C=0.01, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 8/40] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [CV 3/5; 8/40] END C=0.01, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 8/40] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [CV 4/5; 8/40] END C=0.01, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 8/40] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [CV 5/5; 8/40] END C=0.01, gamma=0.001, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 9/40] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 1/5; 9/40] END ..C=0.1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 9/40] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 2/5; 9/40] END ..C=0.1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 9/40] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 3/5; 9/40] END ..C=0.1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 9/40] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 4/5; 9/40] END ..C=0.1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 9/40] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 5/5; 9/40] END ..C=0.1, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5; 10/40] START C=0.1, gamma=1, kernel=sigmoid............................
# [CV 1/5; 10/40] END C=0.1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 10/40] START C=0.1, gamma=1, kernel=sigmoid............................
# [CV 2/5; 10/40] END C=0.1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 10/40] START C=0.1, gamma=1, kernel=sigmoid............................
# [CV 3/5; 10/40] END C=0.1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 10/40] START C=0.1, gamma=1, kernel=sigmoid............................
# [CV 4/5; 10/40] END C=0.1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 10/40] START C=0.1, gamma=1, kernel=sigmoid............................
# [CV 5/5; 10/40] END C=0.1, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 11/40] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 11/40] END C=0.1, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 11/40] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 11/40] END C=0.1, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 11/40] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 11/40] END C=0.1, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 11/40] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 11/40] END C=0.1, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 11/40] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 11/40] END C=0.1, gamma=0.1, kernel=rbf;, score=0.483 total time=   0.0s
# [CV 1/5; 12/40] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [CV 1/5; 12/40] END C=0.1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 12/40] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [CV 2/5; 12/40] END C=0.1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 12/40] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [CV 3/5; 12/40] END C=0.1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 12/40] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [CV 4/5; 12/40] END C=0.1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 12/40] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [CV 5/5; 12/40] END C=0.1, gamma=0.1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 13/40] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 13/40] END C=0.1, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 13/40] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 13/40] END C=0.1, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 13/40] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 13/40] END C=0.1, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 13/40] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 13/40] END C=0.1, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 13/40] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 13/40] END C=0.1, gamma=0.01, kernel=rbf;, score=0.534 total time=   0.0s
# [CV 1/5; 14/40] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [CV 1/5; 14/40] END C=0.1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 14/40] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [CV 2/5; 14/40] END C=0.1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 14/40] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [CV 3/5; 14/40] END C=0.1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 14/40] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [CV 4/5; 14/40] END C=0.1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 14/40] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [CV 5/5; 14/40] END C=0.1, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 15/40] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 1/5; 15/40] END C=0.1, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 15/40] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 2/5; 15/40] END C=0.1, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 15/40] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 3/5; 15/40] END C=0.1, gamma=0.001, kernel=rbf;, score=0.424 total time=   0.0s
# [CV 4/5; 15/40] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 4/5; 15/40] END C=0.1, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 15/40] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 5/5; 15/40] END C=0.1, gamma=0.001, kernel=rbf;, score=0.517 total time=   0.0s
# [CV 1/5; 16/40] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [CV 1/5; 16/40] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 16/40] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [CV 2/5; 16/40] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 16/40] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [CV 3/5; 16/40] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 16/40] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [CV 4/5; 16/40] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 16/40] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [CV 5/5; 16/40] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 17/40] START C=1, gamma=1, kernel=rbf..................................
# [CV 1/5; 17/40] END ...C=1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 17/40] START C=1, gamma=1, kernel=rbf..................................
# [CV 2/5; 17/40] END ...C=1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 17/40] START C=1, gamma=1, kernel=rbf..................................
# [CV 3/5; 17/40] END ...C=1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 17/40] START C=1, gamma=1, kernel=rbf..................................
# [CV 4/5; 17/40] END ...C=1, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 17/40] START C=1, gamma=1, kernel=rbf..................................
# [CV 5/5; 17/40] END ...C=1, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5; 18/40] START C=1, gamma=1, kernel=sigmoid..............................
# [CV 1/5; 18/40] END C=1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 18/40] START C=1, gamma=1, kernel=sigmoid..............................
# [CV 2/5; 18/40] END C=1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 18/40] START C=1, gamma=1, kernel=sigmoid..............................
# [CV 3/5; 18/40] END C=1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 18/40] START C=1, gamma=1, kernel=sigmoid..............................
# [CV 4/5; 18/40] END C=1, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 18/40] START C=1, gamma=1, kernel=sigmoid..............................
# [CV 5/5; 18/40] END C=1, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 19/40] START C=1, gamma=0.1, kernel=rbf................................
# [CV 1/5; 19/40] END .C=1, gamma=0.1, kernel=rbf;, score=0.508 total time=   0.0s
# [CV 2/5; 19/40] START C=1, gamma=0.1, kernel=rbf................................
# [CV 2/5; 19/40] END .C=1, gamma=0.1, kernel=rbf;, score=0.458 total time=   0.0s
# [CV 3/5; 19/40] START C=1, gamma=0.1, kernel=rbf................................
# [CV 3/5; 19/40] END .C=1, gamma=0.1, kernel=rbf;, score=0.542 total time=   0.0s
# [CV 4/5; 19/40] START C=1, gamma=0.1, kernel=rbf................................
# [CV 4/5; 19/40] END .C=1, gamma=0.1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 19/40] START C=1, gamma=0.1, kernel=rbf................................
# [CV 5/5; 19/40] END .C=1, gamma=0.1, kernel=rbf;, score=0.483 total time=   0.0s
# [CV 1/5; 20/40] START C=1, gamma=0.1, kernel=sigmoid............................
# [CV 1/5; 20/40] END C=1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 20/40] START C=1, gamma=0.1, kernel=sigmoid............................
# [CV 2/5; 20/40] END C=1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 20/40] START C=1, gamma=0.1, kernel=sigmoid............................
# [CV 3/5; 20/40] END C=1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 20/40] START C=1, gamma=0.1, kernel=sigmoid............................
# [CV 4/5; 20/40] END C=1, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 20/40] START C=1, gamma=0.1, kernel=sigmoid............................
# [CV 5/5; 20/40] END C=1, gamma=0.1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 21/40] START C=1, gamma=0.01, kernel=rbf...............................
# [CV 1/5; 21/40] END C=1, gamma=0.01, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 2/5; 21/40] START C=1, gamma=0.01, kernel=rbf...............................
# [CV 2/5; 21/40] END C=1, gamma=0.01, kernel=rbf;, score=0.424 total time=   0.0s
# [CV 3/5; 21/40] START C=1, gamma=0.01, kernel=rbf...............................
# [CV 3/5; 21/40] END C=1, gamma=0.01, kernel=rbf;, score=0.475 total time=   0.0s
# [CV 4/5; 21/40] START C=1, gamma=0.01, kernel=rbf...............................
# [CV 4/5; 21/40] END C=1, gamma=0.01, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 5/5; 21/40] START C=1, gamma=0.01, kernel=rbf...............................
# [CV 5/5; 21/40] END C=1, gamma=0.01, kernel=rbf;, score=0.414 total time=   0.0s
# [CV 1/5; 22/40] START C=1, gamma=0.01, kernel=sigmoid...........................
# [CV 1/5; 22/40] END C=1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 22/40] START C=1, gamma=0.01, kernel=sigmoid...........................
# [CV 2/5; 22/40] END C=1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 22/40] START C=1, gamma=0.01, kernel=sigmoid...........................
# [CV 3/5; 22/40] END C=1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 22/40] START C=1, gamma=0.01, kernel=sigmoid...........................
# [CV 4/5; 22/40] END C=1, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 22/40] START C=1, gamma=0.01, kernel=sigmoid...........................
# [CV 5/5; 22/40] END C=1, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 23/40] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 1/5; 23/40] END C=1, gamma=0.001, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 2/5; 23/40] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 2/5; 23/40] END C=1, gamma=0.001, kernel=rbf;, score=0.475 total time=   0.0s
# [CV 3/5; 23/40] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 3/5; 23/40] END C=1, gamma=0.001, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 4/5; 23/40] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 4/5; 23/40] END C=1, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 23/40] START C=1, gamma=0.001, kernel=rbf..............................
# [CV 5/5; 23/40] END C=1, gamma=0.001, kernel=rbf;, score=0.534 total time=   0.0s
# [CV 1/5; 24/40] START C=1, gamma=0.001, kernel=sigmoid..........................
# [CV 1/5; 24/40] END C=1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 24/40] START C=1, gamma=0.001, kernel=sigmoid..........................
# [CV 2/5; 24/40] END C=1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 24/40] START C=1, gamma=0.001, kernel=sigmoid..........................
# [CV 3/5; 24/40] END C=1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 24/40] START C=1, gamma=0.001, kernel=sigmoid..........................
# [CV 4/5; 24/40] END C=1, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 24/40] START C=1, gamma=0.001, kernel=sigmoid..........................
# [CV 5/5; 24/40] END C=1, gamma=0.001, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 25/40] START C=10, gamma=1, kernel=rbf.................................
# [CV 1/5; 25/40] END ..C=10, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 25/40] START C=10, gamma=1, kernel=rbf.................................
# [CV 2/5; 25/40] END ..C=10, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 25/40] START C=10, gamma=1, kernel=rbf.................................
# [CV 3/5; 25/40] END ..C=10, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 25/40] START C=10, gamma=1, kernel=rbf.................................
# [CV 4/5; 25/40] END ..C=10, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 25/40] START C=10, gamma=1, kernel=rbf.................................
# [CV 5/5; 25/40] END ..C=10, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5; 26/40] START C=10, gamma=1, kernel=sigmoid.............................
# [CV 1/5; 26/40] END C=10, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 26/40] START C=10, gamma=1, kernel=sigmoid.............................
# [CV 2/5; 26/40] END C=10, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 26/40] START C=10, gamma=1, kernel=sigmoid.............................
# [CV 3/5; 26/40] END C=10, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 26/40] START C=10, gamma=1, kernel=sigmoid.............................
# [CV 4/5; 26/40] END C=10, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 26/40] START C=10, gamma=1, kernel=sigmoid.............................
# [CV 5/5; 26/40] END C=10, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 27/40] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 27/40] END C=10, gamma=0.1, kernel=rbf;, score=0.508 total time=   0.0s
# [CV 2/5; 27/40] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 27/40] END C=10, gamma=0.1, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 3/5; 27/40] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 27/40] END C=10, gamma=0.1, kernel=rbf;, score=0.559 total time=   0.0s
# [CV 4/5; 27/40] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 27/40] END C=10, gamma=0.1, kernel=rbf;, score=0.475 total time=   0.0s
# [CV 5/5; 27/40] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 27/40] END C=10, gamma=0.1, kernel=rbf;, score=0.448 total time=   0.0s
# [CV 1/5; 28/40] START C=10, gamma=0.1, kernel=sigmoid...........................
# [CV 1/5; 28/40] END C=10, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 28/40] START C=10, gamma=0.1, kernel=sigmoid...........................
# [CV 2/5; 28/40] END C=10, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 28/40] START C=10, gamma=0.1, kernel=sigmoid...........................
# [CV 3/5; 28/40] END C=10, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 28/40] START C=10, gamma=0.1, kernel=sigmoid...........................
# [CV 4/5; 28/40] END C=10, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 28/40] START C=10, gamma=0.1, kernel=sigmoid...........................
# [CV 5/5; 28/40] END C=10, gamma=0.1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 29/40] START C=10, gamma=0.01, kernel=rbf..............................
# [CV 1/5; 29/40] END C=10, gamma=0.01, kernel=rbf;, score=0.390 total time=   0.0s
# [CV 2/5; 29/40] START C=10, gamma=0.01, kernel=rbf..............................
# [CV 2/5; 29/40] END C=10, gamma=0.01, kernel=rbf;, score=0.356 total time=   0.0s
# [CV 3/5; 29/40] START C=10, gamma=0.01, kernel=rbf..............................
# [CV 3/5; 29/40] END C=10, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 29/40] START C=10, gamma=0.01, kernel=rbf..............................
# [CV 4/5; 29/40] END C=10, gamma=0.01, kernel=rbf;, score=0.559 total time=   0.0s
# [CV 5/5; 29/40] START C=10, gamma=0.01, kernel=rbf..............................
# [CV 5/5; 29/40] END C=10, gamma=0.01, kernel=rbf;, score=0.362 total time=   0.0s
# [CV 1/5; 30/40] START C=10, gamma=0.01, kernel=sigmoid..........................
# [CV 1/5; 30/40] END C=10, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 30/40] START C=10, gamma=0.01, kernel=sigmoid..........................
# [CV 2/5; 30/40] END C=10, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 30/40] START C=10, gamma=0.01, kernel=sigmoid..........................
# [CV 3/5; 30/40] END C=10, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 30/40] START C=10, gamma=0.01, kernel=sigmoid..........................
# [CV 4/5; 30/40] END C=10, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 30/40] START C=10, gamma=0.01, kernel=sigmoid..........................
# [CV 5/5; 30/40] END C=10, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 31/40] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 31/40] END C=10, gamma=0.001, kernel=rbf;, score=0.390 total time=   0.0s
# [CV 2/5; 31/40] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 31/40] END C=10, gamma=0.001, kernel=rbf;, score=0.458 total time=   0.0s
# [CV 3/5; 31/40] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 31/40] END C=10, gamma=0.001, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 4/5; 31/40] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 31/40] END C=10, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 31/40] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 31/40] END C=10, gamma=0.001, kernel=rbf;, score=0.586 total time=   0.0s
# [CV 1/5; 32/40] START C=10, gamma=0.001, kernel=sigmoid.........................
# [CV 1/5; 32/40] END C=10, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 32/40] START C=10, gamma=0.001, kernel=sigmoid.........................
# [CV 2/5; 32/40] END C=10, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 32/40] START C=10, gamma=0.001, kernel=sigmoid.........................
# [CV 3/5; 32/40] END C=10, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 32/40] START C=10, gamma=0.001, kernel=sigmoid.........................
# [CV 4/5; 32/40] END C=10, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 32/40] START C=10, gamma=0.001, kernel=sigmoid.........................
# [CV 5/5; 32/40] END C=10, gamma=0.001, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 33/40] START C=100, gamma=1, kernel=rbf................................
# [CV 1/5; 33/40] END .C=100, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 2/5; 33/40] START C=100, gamma=1, kernel=rbf................................
# [CV 2/5; 33/40] END .C=100, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 3/5; 33/40] START C=100, gamma=1, kernel=rbf................................
# [CV 3/5; 33/40] END .C=100, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 33/40] START C=100, gamma=1, kernel=rbf................................
# [CV 4/5; 33/40] END .C=100, gamma=1, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 5/5; 33/40] START C=100, gamma=1, kernel=rbf................................
# [CV 5/5; 33/40] END .C=100, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5; 34/40] START C=100, gamma=1, kernel=sigmoid............................
# [CV 1/5; 34/40] END C=100, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 34/40] START C=100, gamma=1, kernel=sigmoid............................
# [CV 2/5; 34/40] END C=100, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 34/40] START C=100, gamma=1, kernel=sigmoid............................
# [CV 3/5; 34/40] END C=100, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 34/40] START C=100, gamma=1, kernel=sigmoid............................
# [CV 4/5; 34/40] END C=100, gamma=1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 34/40] START C=100, gamma=1, kernel=sigmoid............................
# [CV 5/5; 34/40] END C=100, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 35/40] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 35/40] END C=100, gamma=0.1, kernel=rbf;, score=0.508 total time=   0.0s
# [CV 2/5; 35/40] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 35/40] END C=100, gamma=0.1, kernel=rbf;, score=0.441 total time=   0.0s
# [CV 3/5; 35/40] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 35/40] END C=100, gamma=0.1, kernel=rbf;, score=0.559 total time=   0.0s
# [CV 4/5; 35/40] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 35/40] END C=100, gamma=0.1, kernel=rbf;, score=0.475 total time=   0.0s
# [CV 5/5; 35/40] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 35/40] END C=100, gamma=0.1, kernel=rbf;, score=0.448 total time=   0.0s
# [CV 1/5; 36/40] START C=100, gamma=0.1, kernel=sigmoid..........................
# [CV 1/5; 36/40] END C=100, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 36/40] START C=100, gamma=0.1, kernel=sigmoid..........................
# [CV 2/5; 36/40] END C=100, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 36/40] START C=100, gamma=0.1, kernel=sigmoid..........................
# [CV 3/5; 36/40] END C=100, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 36/40] START C=100, gamma=0.1, kernel=sigmoid..........................
# [CV 4/5; 36/40] END C=100, gamma=0.1, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 36/40] START C=100, gamma=0.1, kernel=sigmoid..........................
# [CV 5/5; 36/40] END C=100, gamma=0.1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 37/40] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 1/5; 37/40] END C=100, gamma=0.01, kernel=rbf;, score=0.390 total time=   0.0s
# [CV 2/5; 37/40] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 2/5; 37/40] END C=100, gamma=0.01, kernel=rbf;, score=0.356 total time=   0.0s
# [CV 3/5; 37/40] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 3/5; 37/40] END C=100, gamma=0.01, kernel=rbf;, score=0.492 total time=   0.0s
# [CV 4/5; 37/40] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 4/5; 37/40] END C=100, gamma=0.01, kernel=rbf;, score=0.559 total time=   0.0s
# [CV 5/5; 37/40] START C=100, gamma=0.01, kernel=rbf.............................
# [CV 5/5; 37/40] END C=100, gamma=0.01, kernel=rbf;, score=0.362 total time=   0.0s
# [CV 1/5; 38/40] START C=100, gamma=0.01, kernel=sigmoid.........................
# [CV 1/5; 38/40] END C=100, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 38/40] START C=100, gamma=0.01, kernel=sigmoid.........................
# [CV 2/5; 38/40] END C=100, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 38/40] START C=100, gamma=0.01, kernel=sigmoid.........................
# [CV 3/5; 38/40] END C=100, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 38/40] START C=100, gamma=0.01, kernel=sigmoid.........................
# [CV 4/5; 38/40] END C=100, gamma=0.01, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 38/40] START C=100, gamma=0.01, kernel=sigmoid.........................
# [CV 5/5; 38/40] END C=100, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 1/5; 39/40] START C=100, gamma=0.001, kernel=rbf............................
# [CV 1/5; 39/40] END C=100, gamma=0.001, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 2/5; 39/40] START C=100, gamma=0.001, kernel=rbf............................
# [CV 2/5; 39/40] END C=100, gamma=0.001, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 3/5; 39/40] START C=100, gamma=0.001, kernel=rbf............................
# [CV 3/5; 39/40] END C=100, gamma=0.001, kernel=rbf;, score=0.475 total time=   0.0s
# [CV 4/5; 39/40] START C=100, gamma=0.001, kernel=rbf............................
# [CV 4/5; 39/40] END C=100, gamma=0.001, kernel=rbf;, score=0.458 total time=   0.0s
# [CV 5/5; 39/40] START C=100, gamma=0.001, kernel=rbf............................
# [CV 5/5; 39/40] END C=100, gamma=0.001, kernel=rbf;, score=0.552 total time=   0.0s
# [CV 1/5; 40/40] START C=100, gamma=0.001, kernel=sigmoid........................
# [CV 1/5; 40/40] END C=100, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 2/5; 40/40] START C=100, gamma=0.001, kernel=sigmoid........................
# [CV 2/5; 40/40] END C=100, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 3/5; 40/40] START C=100, gamma=0.001, kernel=sigmoid........................
# [CV 3/5; 40/40] END C=100, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 4/5; 40/40] START C=100, gamma=0.001, kernel=sigmoid........................
# [CV 4/5; 40/40] END C=100, gamma=0.001, kernel=sigmoid;, score=0.492 total time=   0.0s
# [CV 5/5; 40/40] START C=100, gamma=0.001, kernel=sigmoid........................
# [CV 5/5; 40/40] END C=100, gamma=0.001, kernel=sigmoid;, score=0.500 total time=   0.0s

# %%
grid.best_score_
# Out:
# 0.5001168907071888

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
