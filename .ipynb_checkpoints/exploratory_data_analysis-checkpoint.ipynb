# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import missingno as msno
from collections import Counter

# %% [markdown]
# ## Raw data:

# %%
data = pd.read_csv("./dataset/maps-synthetic-data-v1.1.csv", engine='python')
data.head()
# Out:
#    Unnamed: 0  X       flag comp_bed_9  mat_dep mat_age  weight_16  \
# 0           1  1  synthetic        NaN      3.0      30  59.294132
# 1           2  2  synthetic        NaN      9.0      26        NaN
# 2           3  3  synthetic        NaN      3.0      24        NaN
# 3           4  4  synthetic         No      NaN      22  49.812426
# 4           5  5  synthetic         No      8.0      31  62.270030
#
#     height_16     iq comp_noint_bed_16  ... dep_score comp_house tv_bed_16  \
# 0  181.602831  107.0               NaN  ...       0.0        Yes       Yes
# 1         NaN   85.0               NaN  ...       NaN        NaN       NaN
# 2         NaN    NaN               NaN  ...       NaN        NaN       NaN
# 3  160.224186    NaN               NaN  ...       NaN        NaN       NaN
# 4  191.703227  132.0               Yes  ...       NaN        NaN       NaN
#
#   creat_14 comp_games      fam_tv_eve      fam_tv_aft      fam_tv_mor     sex  \
# 0    often         No  Yes, Some Days           Other  Yes, Every Day  Female
# 1      NaN        NaN             NaN             NaN             NaN  Female
# 2      NaN        NaN  Yes, Some Days  Yes, Every Day           Other    Male
# 3      NaN         No             NaN             NaN             NaN    Male
# 4    often         No  Yes, Some Days  Yes, Every Day  Yes, Every Day  Female
#
#   birth_order
# 0           A
# 1           B
# 2           A
# 3           A
# 4           A
#
# [5 rows x 85 columns]

# %%
dictionary = pd.read_csv("./dataset/synthetic_data_dictionary.csv", engine='python')
dictionary.head()
# Out:
#   Variable Name Variable ALSPAC Name  \
# 0     agg_score                 f596
# 1     alon_week              ccs1006
# 2           NaN                  NaN
# 3
# 4
#
#                                 Variable Description Variable Type  \
# 0                    Aggression score of partnership      Discrete
# 1  Average time child spent per day doing things ...       Ordinal
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   Administered to Age of child at administration  \
# 0          Mother                  Aged 8 months
# 1           Child                Aged 198 months
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
#
#                                       ALSPAC Measure  ALSPAC Responses  \
# 0          Derived by ALSPAC. See Processing Details               NaN
# 1  "How much time on average do you spend each da...        Not at all
# 2                                                NaN  Less than 1 hour
# 3                                                NaN         1-2 hours
# 4                                                NaN   3 or more hours
#
#                                   Processing Details Reference Document
# 0  Aggression score was determined by three quest...                NaN
# 1  The category "Not at all" was collapsed into t...                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN

# %% [markdown]
# Variables have different Age Of Child At Administration parameters. We don't need the variables with this parameter not equal to 16 (for variables related to screen time) and 18 (for variables related to a depression or anxiety diagnosis).

# %% [markdown]
# ## only the columns at 16 and 18:

# %% [markdown]
# All vars at 16 are separated into weekend and weekdays. Might be worth summing it up into total per week.

# %%
rows = dictionary[(dictionary["Age of child at administration"] == "Aged 198 months")]
rows2 = dictionary[(dictionary["Age of child at administration"] == "Aged around 17.5 years")]
rows3 = dictionary[(dictionary["Age of child at administration"] == "Aged around 15.5 years")]

columns_to_keep_names = list(rows['Variable Name'].append(rows2['Variable Name']).append(rows3['Variable Name']))

print(columns_to_keep_names)
# Out:
# ['alon_week', 'alon_wend', 'child_bull', 'comp_house', 'comp_int_bed_16', 'comp_noint_bed_16', 'comp_week', 'comp_wend', 'draw_week', 'draw_wend', 'exercise', 'musi_week', 'musi_wend', 'out_sum_week', 'out_sum_wend', 'out_win_week', 'out_win_wend', 'play_week', 'play_wend', 'read_week', 'read_wend', 'talk_mob_week', 'talk_mob_wend', 'talk_phon_week', 'talk_phon_wend', 'text_week', 'text_wend', 'tran_week', 'tran_wend', 'tv_week', 'tv_wend', 'work_week', 'work_wend', 'dep_score', 'dep_thoughts', 'has_dep_diag', 'panic_score', 'prim_diag', 'secd_diag', 'anx_band_15', 'dep_band_15', 'height_16', 'weight_16']
# C:\Users\moham\AppData\Local\Temp/ipykernel_24488/2955949351.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   columns_to_keep_names = list(rows['Variable Name'].append(rows2['Variable Name']).append(rows3['Variable Name']))
# C:\Users\moham\AppData\Local\Temp/ipykernel_24488/2955949351.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   columns_to_keep_names = list(rows['Variable Name'].append(rows2['Variable Name']).append(rows3['Variable Name']))

# %% [markdown]
# ## Remove vars at wrong ages: TO FIX!!

# %%
df = pd.DataFrame(data)
for i in df.columns:
    if (i in columns_to_keep_names):
        print(i, "keep")
    else: df.drop(i, inplace = True, axis = 1)
# Out:
# weight_16 keep
# height_16 keep
# comp_noint_bed_16 keep
# comp_int_bed_16 keep
# talk_phon_wend keep
# text_wend keep
# talk_mob_wend keep
# comp_wend keep
# musi_wend keep
# read_wend keep
# work_wend keep
# alon_wend keep
# draw_wend keep
# play_wend keep
# tv_wend keep
# out_win_wend keep
# out_sum_wend keep
# tran_wend keep
# talk_phon_week keep
# text_week keep
# talk_mob_week keep
# comp_week keep
# musi_week keep
# read_week keep
# work_week keep
# alon_week keep
# draw_week keep
# play_week keep
# tv_week keep
# out_win_week keep
# out_sum_week keep
# tran_week keep
# dep_band_15 keep
# anx_band_15 keep
# exercise keep
# child_bull keep
# has_dep_diag keep
# secd_diag keep
# prim_diag keep
# panic_score keep
# dep_thoughts keep
# dep_score keep
# comp_house keep

# %% [markdown]
# ## Mohammed's stuff:

# %%
data = df
print(data.columns)
for i in data.columns:
    if len(data[i].unique()) <= 7:
        m = 1
        #print(i, data[i].unique())
# Out:
# Index(['weight_16', 'height_16', 'comp_noint_bed_16', 'comp_int_bed_16',
#        'talk_phon_wend', 'text_wend', 'talk_mob_wend', 'comp_wend',
#        'musi_wend', 'read_wend', 'work_wend', 'alon_wend', 'draw_wend',
#        'play_wend', 'tv_wend', 'out_win_wend', 'out_sum_wend', 'tran_wend',
#        'talk_phon_week', 'text_week', 'talk_mob_week', 'comp_week',
#        'musi_week', 'read_week', 'work_week', 'alon_week', 'draw_week',
#        'play_week', 'tv_week', 'out_win_week', 'out_sum_week', 'tran_week',
#        'dep_band_15', 'anx_band_15', 'exercise', 'child_bull', 'has_dep_diag',
#        'secd_diag', 'prim_diag', 'panic_score', 'dep_thoughts', 'dep_score',
#        'comp_house'],
#       dtype='object')

# %%
for i in ['comp_bed_9', 'pat_pres_10', 'pat_pres_8', 'pat_pres', 'mat_anx_1', 'mat_anx_18m', 'mat_anx_8m', 'emot_cruel',
          'phys_cruel', 'mat_anx_0m', 'child_bull', 'musi_13', 'tv_bed_9', 'own_mob', 'comp_games']:
    if(i in data.columns):
        data[i] = data[i].replace(['Yes'], True)
        data[i] = data[i].replace(['No'], False)
    
for i in ['comp_noint_bed_16', 'comp_int_bed_16', 'comp_house', 'tv_bed_16']:
    if(i in data.columns):
        data[i] = data[i].replace(['Yes'], True)
        data[i] = data[i].fillna(False)
    
for i in ['talk_phon_wend', 'musi_wend', 'talk_phon_week', 'musi_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Not at all'], False)
        data[i] = data[i].replace(['Any at all'], True)

for i in ['play_wend', 'out_sum_wend', 'play_week', 'out_sum_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Less than 3 hours'], False)
        data[i] = data[i].replace(['3 or more hours'], True)
    
for i in ['tran_wend', 'tran_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Less than 1 hour'], False)
        data[i] = data[i].replace(['1 or more hours'], True)
    
data.head()
# Out:
#    weight_16   height_16  comp_noint_bed_16  comp_int_bed_16 talk_phon_wend  \
# 0  59.294132  181.602831              False            False           True
# 1        NaN         NaN              False            False            NaN
# 2        NaN         NaN              False            False            NaN
# 3  49.812426  160.224186              False            False            NaN
# 4  62.270030  191.703227               True            False          False
#
#           text_wend     talk_mob_wend         comp_wend musi_wend  \
# 0  Less than 1 hour  Less than 1 hour         1-2 hours     False
# 1               NaN               NaN               NaN       NaN
# 2               NaN               NaN               NaN       NaN
# 3               NaN               NaN               NaN       NaN
# 4        Not at all        Not at all  Less than 1 hour     False
#
#           read_wend  ... anx_band_15                exercise child_bull  \
# 0  Less than 1 hour  ...       ~0.5%  5 or more times a week      False
# 1               NaN  ...         NaN                     NaN        NaN
# 2               NaN  ...         NaN                     NaN        NaN
# 3               NaN  ...         NaN                     NaN        NaN
# 4   1 or more hours  ...         ~3%        1-4 times a week      False
#
#                          has_dep_diag secd_diag prim_diag panic_score  \
# 0   No ICD-10 diagnosis of depression       0.0       0.0         0.0
# 1                                 NaN       NaN       NaN         NaN
# 2                                 NaN       NaN       NaN         NaN
# 3                                 NaN       NaN       NaN         NaN
# 4                                 NaN       NaN       NaN         NaN
#
#   dep_thoughts dep_score comp_house
# 0          NaN       0.0       True
# 1          NaN       NaN      False
# 2          NaN       NaN      False
# 3          NaN       NaN      False
# 4          NaN       NaN      False
#
# [5 rows x 43 columns]

# %%
for i in ['talk_mob_wend', 'read_wend', 'draw_wend', 'talk_mob_week', 'read_week', 'draw_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Not at all', 'Less than 1 hour', '1 or more hours'], range(3))
    
for i in ['work_wend', 'alon_wend', 'out_win_wend', 'work_week', 'alon_week', 'out_win_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Less than 1 hour', '1-2 hours', '3 or more hours'], range(3))
    
for i in ['phone_14_wend', 'phone_14_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Not at all', '< 1 hour', '1 or more hours'], range(3))
    
for i in ['fam_tv_eve', 'fam_tv_aft', 'fam_tv_mor']:
    if(i in data.columns):
        data[i] = data[i].replace(['Other', 'Yes, Some Days', 'Yes, Every Day'], range(3))

# %%
for i in ['text_wend', 'comp_wend', 'tv_wend', 'text_week', 'comp_week', 'tv_week']:
    if(i in data.columns):
        data[i] = data[i].replace(['Not at all', 'Less than 1 hour', '1-2 hours', '3 or more hours'], range(4))

# %%
percentages = ['dep_band_07', 'dep_band_15', 'dep_band_13', 'dep_band_10', 'anx_band_15', 'anx_band_07',
               'anx_band_13', 'anx_band_10']
for i in percentages:
    if(i in data.columns):
        data[i] = data[i].str.strip('%<>~').astype('float')

# %%
#data['exercise'] = data['exercise'].replace(['Never', 'Less than once a month', '1-3 times a month',
                                             #'1-4 times a week', '5 or more times a week'], range(5))

#data['num_home'] = data['num_home'].replace(['9 or more'], '9').astype('float')

# %%
#data['mat_age'] = data['mat_age'].replace(['< 16','>43'], ['15', '44']).astype('float')

data['weight_16'].round(decimals = 2)
data['height_16'].round(decimals = 2)
# Out:
# 0        181.60
# 1           NaN
# 2           NaN
# 3        160.22
# 4        191.70
#           ...
# 13729       NaN
# 13730       NaN
# 13731    169.24
# 13732       NaN
# 13733    176.87
# Name: height_16, Length: 13734, dtype: float64

# %% [markdown]
# # Combining variable

# %%
add1 = ['alon_week','draw_week','musi_week','out_sum_week','play_week','read_week','text_week',
        'tran_week','work_week','comp_week','tv_week','talk_mob_week','talk_phon_week']
add2 = ['alon_wend','draw_wend','musi_wend','out_sum_wend','play_wend','read_wend','text_wend',
        'tran_wend','work_wend','comp_wend','tv_wend','talk_mob_wend','talk_phon_wend']

data['alon'] = data['alon_week'] + data['alon_wend']
data['draw'] = data['draw_week'] + data['draw_wend']
data['musi'] = data['musi_week'] + data['musi_wend']
data['out_sum'] = data['out_sum_week'] + data['out_sum_wend']
data['play'] = data['play_week'] + data['play_wend']
data['read'] = data['read_week'] + data['read_wend']
data['text'] = data['text_week'] + data['text_wend']
data['tran'] = data['tran_week'] + data['tran_wend']
data['work'] = data['work_week'] + data['work_wend']
data['comp'] = data['comp_week'] + data['comp_wend']
data['comp_bed_16'] = (data['comp_int_bed_16'] | data['comp_noint_bed_16'])
data['comp'] = (data['comp_int_bed_16'] | data['comp_noint_bed_16'] | data['comp_house'])
data['tv'] = data['tv_week'] + data['tv_wend']
data['talk_mob'] = data['talk_mob_week'] + data['talk_mob_wend']
data['talk_phon'] = data['talk_phon_week'] + data['talk_phon_wend']
error = []
for i in data.index:
    for j in range(len(add1)):
        if(type(data[add1[j]][i]) != type(data[add2[j]][i])):
            if(add1[j] not in error):
                error.append(add1[j])

# %%
for i in error:
    print(i , data[i].unique())
# Out:
# out_sum_week [True nan False]
# musi_week [False nan True]
# play_week [True nan False]
# talk_phon_week [False nan True]
# tran_week [False nan True]

# %% [markdown]
# ## Mohamed's stuff

# %%
transposed_data = data.T
transposed_data
# Out:
#                                                 0      1      2      \
# weight_16                                   59.294132    NaN    NaN
# height_16                                  181.602831    NaN    NaN
# comp_noint_bed_16                               False  False  False
# comp_int_bed_16                                 False  False  False
# talk_phon_wend                                   True    NaN    NaN
# text_wend                                         1.0    NaN    NaN
# talk_mob_wend                                     1.0    NaN    NaN
# comp_wend                                         2.0    NaN    NaN
# musi_wend                                       False    NaN    NaN
# read_wend                                         1.0    NaN    NaN
# work_wend                                         2.0    NaN    NaN
# alon_wend                                         1.0    NaN    NaN
# draw_wend                                         0.0    NaN    NaN
# play_wend                                        True    NaN    NaN
# tv_wend                                           2.0    NaN    NaN
# out_win_wend                                      2.0    NaN    NaN
# out_sum_wend                                     True    NaN    NaN
# tran_wend                                       False    NaN    NaN
# talk_phon_week                                  False    NaN    NaN
# text_week                                         1.0    NaN    NaN
# talk_mob_week                                     1.0    NaN    NaN
# comp_week                                         2.0    NaN    NaN
# musi_week                                       False    NaN    NaN
# read_week                                         1.0    NaN    NaN
# work_week                                         2.0    NaN    NaN
# alon_week                                         1.0    NaN    NaN
# draw_week                                         0.0    NaN    NaN
# play_week                                        True    NaN    NaN
# tv_week                                           2.0    NaN    NaN
# out_win_week                                      2.0    NaN    NaN
# out_sum_week                                     True    NaN    NaN
# tran_week                                       False    NaN    NaN
# dep_band_15                                       0.5    NaN    NaN
# anx_band_15                                       0.5    NaN    NaN
# exercise                       5 or more times a week    NaN    NaN
# child_bull                                      False    NaN    NaN
# has_dep_diag        No ICD-10 diagnosis of depression    NaN    NaN
# secd_diag                                         0.0    NaN    NaN
# prim_diag                                         0.0    NaN    NaN
# panic_score                                       0.0    NaN    NaN
# dep_thoughts                                      NaN    NaN    NaN
# dep_score                                         0.0    NaN    NaN
# comp_house                                       True  False  False
# alon                                              2.0    NaN    NaN
# draw                                              0.0    NaN    NaN
# musi                                                0    NaN    NaN
# out_sum                                             2    NaN    NaN
# play                                                2    NaN    NaN
# read                                              2.0    NaN    NaN
# text                                              2.0    NaN    NaN
# tran                                                0    NaN    NaN
# work                                              4.0    NaN    NaN
# comp                                             True  False  False
# comp_bed_16                                     False  False  False
# tv                                                4.0    NaN    NaN
# talk_mob                                          2.0    NaN    NaN
# talk_phon                                           1    NaN    NaN
#
#                         3                 4      \
# weight_16           49.812426          62.27003
# height_16          160.224186        191.703227
# comp_noint_bed_16       False              True
# comp_int_bed_16         False             False
# talk_phon_wend            NaN             False
# text_wend                 NaN               0.0
# talk_mob_wend             NaN               0.0
# comp_wend                 NaN               1.0
# musi_wend                 NaN             False
# read_wend                 NaN               2.0
# work_wend                 NaN               1.0
# alon_wend                 NaN               2.0
# draw_wend                 NaN               0.0
# play_wend                 NaN             False
# tv_wend                   NaN               3.0
# out_win_wend              NaN               0.0
# out_sum_wend              NaN             False
# tran_wend                 NaN             False
# talk_phon_week            NaN             False
# text_week                 NaN               0.0
# talk_mob_week             NaN               0.0
# comp_week                 NaN               2.0
# musi_week                 NaN             False
# read_week                 NaN               2.0
# work_week                 NaN               1.0
# alon_week                 NaN               1.0
# draw_week                 NaN               0.0
# play_week                 NaN              True
# tv_week                   NaN               2.0
# out_win_week              NaN               0.0
# out_sum_week              NaN             False
# tran_week                 NaN             False
# dep_band_15               NaN               0.1
# anx_band_15               NaN               3.0
# exercise                  NaN  1-4 times a week
# child_bull                NaN             False
# has_dep_diag              NaN               NaN
# secd_diag                 NaN               NaN
# prim_diag                 NaN               NaN
# panic_score               NaN               NaN
# dep_thoughts              NaN               NaN
# dep_score                 NaN               NaN
# comp_house              False             False
# alon                      NaN               3.0
# draw                      NaN               0.0
# musi                      NaN                 0
# out_sum                   NaN                 0
# play                      NaN                 1
# read                      NaN               4.0
# text                      NaN               0.0
# tran                      NaN                 0
# work                      NaN               2.0
# comp                    False              True
# comp_bed_16             False              True
# tv                        NaN               5.0
# talk_mob                  NaN               0.0
# talk_phon                 NaN                 0
#
#                                                 5      6      \
# weight_16                                   78.936613    NaN
# height_16                                  169.722373    NaN
# comp_noint_bed_16                               False  False
# comp_int_bed_16                                 False  False
# talk_phon_wend                                   True    NaN
# text_wend                                         1.0    NaN
# talk_mob_wend                                     1.0    NaN
# comp_wend                                         1.0    NaN
# musi_wend                                       False    NaN
# read_wend                                         1.0    NaN
# work_wend                                         0.0    NaN
# alon_wend                                         2.0    NaN
# draw_wend                                         0.0    NaN
# play_wend                                        True    NaN
# tv_wend                                           3.0    NaN
# out_win_wend                                      1.0    NaN
# out_sum_wend                                     True    NaN
# tran_wend                                       False    NaN
# talk_phon_week                                   True    NaN
# text_week                                         1.0    NaN
# talk_mob_week                                     1.0    NaN
# comp_week                                         2.0    NaN
# musi_week                                       False    NaN
# read_week                                         1.0    NaN
# work_week                                         2.0    NaN
# alon_week                                         NaN    NaN
# draw_week                                         0.0    NaN
# play_week                                        True    NaN
# tv_week                                           2.0    NaN
# out_win_week                                      2.0    NaN
# out_sum_week                                     True    NaN
# tran_week                                        True    NaN
# dep_band_15                                       0.5    NaN
# anx_band_15                                       0.5    NaN
# exercise                            1-3 times a month    NaN
# child_bull                                      False    NaN
# has_dep_diag        No ICD-10 diagnosis of depression    NaN
# secd_diag                                         0.0    NaN
# prim_diag                                         0.0    NaN
# panic_score                                       0.0    NaN
# dep_thoughts                                      NaN    NaN
# dep_score                                         0.0    NaN
# comp_house                                      False  False
# alon                                              NaN    NaN
# draw                                              0.0    NaN
# musi                                                0    NaN
# out_sum                                             2    NaN
# play                                                2    NaN
# read                                              2.0    NaN
# text                                              2.0    NaN
# tran                                                1    NaN
# work                                              2.0    NaN
# comp                                            False  False
# comp_bed_16                                     False  False
# tv                                                5.0    NaN
# talk_mob                                          2.0    NaN
# talk_phon                                           2    NaN
#
#                                                 7      \
# weight_16                                   84.299663
# height_16                                  186.327284
# comp_noint_bed_16                               False
# comp_int_bed_16                                 False
# talk_phon_wend                                    NaN
# text_wend                                         NaN
# talk_mob_wend                                     NaN
# comp_wend                                         NaN
# musi_wend                                         NaN
# read_wend                                         NaN
# work_wend                                         NaN
# alon_wend                                         NaN
# draw_wend                                         NaN
# play_wend                                         NaN
# tv_wend                                           NaN
# out_win_wend                                      NaN
# out_sum_wend                                      NaN
# tran_wend                                         NaN
# talk_phon_week                                    NaN
# text_week                                         NaN
# talk_mob_week                                     NaN
# comp_week                                         NaN
# musi_week                                         NaN
# read_week                                         NaN
# work_week                                         NaN
# alon_week                                         NaN
# draw_week                                         NaN
# play_week                                         NaN
# tv_week                                           NaN
# out_win_week                                      NaN
# out_sum_week                                      NaN
# tran_week                                         NaN
# dep_band_15                                       0.1
# anx_band_15                                       3.0
# exercise                                          NaN
# child_bull                                        NaN
# has_dep_diag        No ICD-10 diagnosis of depression
# secd_diag                                         0.0
# prim_diag                                         0.0
# panic_score                                       0.0
# dep_thoughts                                      NaN
# dep_score                                         0.0
# comp_house                                      False
# alon                                              NaN
# draw                                              NaN
# musi                                              NaN
# out_sum                                           NaN
# play                                              NaN
# read                                              NaN
# text                                              NaN
# tran                                              NaN
# work                                              NaN
# comp                                            False
# comp_bed_16                                     False
# tv                                                NaN
# talk_mob                                          NaN
# talk_phon                                         NaN
#
#                                                 8           9      ...  \
# weight_16                                   70.657258   70.529403  ...
# height_16                                  176.027653  187.778207  ...
# comp_noint_bed_16                               False       False  ...
# comp_int_bed_16                                  True       False  ...
# talk_phon_wend                                   True         NaN  ...
# text_wend                                         1.0         NaN  ...
# talk_mob_wend                                     1.0         NaN  ...
# comp_wend                                         3.0         NaN  ...
# musi_wend                                        True         NaN  ...
# read_wend                                         0.0         NaN  ...
# work_wend                                         2.0         NaN  ...
# alon_wend                                         1.0         NaN  ...
# draw_wend                                         1.0         NaN  ...
# play_wend                                        True         NaN  ...
# tv_wend                                           2.0         NaN  ...
# out_win_wend                                      2.0         NaN  ...
# out_sum_wend                                     True         NaN  ...
# tran_wend                                        True         NaN  ...
# talk_phon_week                                   True         NaN  ...
# text_week                                         3.0         NaN  ...
# talk_mob_week                                     2.0         NaN  ...
# comp_week                                         3.0         NaN  ...
# musi_week                                        True         NaN  ...
# read_week                                         0.0         NaN  ...
# work_week                                         2.0         NaN  ...
# alon_week                                         1.0         NaN  ...
# draw_week                                         1.0         NaN  ...
# play_week                                        True         NaN  ...
# tv_week                                           2.0         NaN  ...
# out_win_week                                      2.0         NaN  ...
# out_sum_week                                     True         NaN  ...
# tran_week                                        True         NaN  ...
# dep_band_15                                      15.0         0.5  ...
# anx_band_15                                      15.0         0.5  ...
# exercise                       5 or more times a week         NaN  ...
# child_bull                                      False         NaN  ...
# has_dep_diag        No ICD-10 diagnosis of depression         NaN  ...
# secd_diag                                         0.0         NaN  ...
# prim_diag                                         5.0         NaN  ...
# panic_score                                       0.0         NaN  ...
# dep_thoughts                                      NaN         NaN  ...
# dep_score                                         0.0         NaN  ...
# comp_house                                      False       False  ...
# alon                                              2.0         NaN  ...
# draw                                              2.0         NaN  ...
# musi                                                2         NaN  ...
# out_sum                                             2         NaN  ...
# play                                                2         NaN  ...
# read                                              0.0         NaN  ...
# text                                              4.0         NaN  ...
# tran                                                2         NaN  ...
# work                                              4.0         NaN  ...
# comp                                             True       False  ...
# comp_bed_16                                      True       False  ...
# tv                                                4.0         NaN  ...
# talk_mob                                          3.0         NaN  ...
# talk_phon                                           2         NaN  ...
#
#                               13724                               13725  \
# weight_16                       NaN                                 NaN
# height_16                       NaN                                 NaN
# comp_noint_bed_16             False                               False
# comp_int_bed_16               False                                True
# talk_phon_wend                False                                True
# text_wend                       2.0                                 1.0
# talk_mob_wend                   1.0                                 1.0
# comp_wend                       2.0                                 3.0
# musi_wend                     False                                True
# read_wend                       2.0                                 2.0
# work_wend                       1.0                                 0.0
# alon_wend                       1.0                                 0.0
# draw_wend                       0.0                                 1.0
# play_wend                     False                                True
# tv_wend                         2.0                                 2.0
# out_win_wend                    1.0                                 2.0
# out_sum_wend                  False                                True
# tran_wend                     False                               False
# talk_phon_week                False                                True
# text_week                       2.0                                 1.0
# talk_mob_week                   1.0                                 1.0
# comp_week                       2.0                                 2.0
# musi_week                     False                                True
# read_week                       2.0                                 2.0
# work_week                       1.0                                 2.0
# alon_week                       1.0                                 0.0
# draw_week                       0.0                                 2.0
# play_week                     False                                True
# tv_week                         2.0                                 1.0
# out_win_week                    0.0                                 1.0
# out_sum_week                  False                                True
# tran_week                     False                               False
# dep_band_15                     NaN                                 NaN
# anx_band_15                     NaN                                 NaN
# exercise           1-4 times a week              Less than once a month
# child_bull                    False                               False
# has_dep_diag                    NaN  Yes ICD-10 diagnosis of depression
# secd_diag                       NaN                                 7.0
# prim_diag                       NaN                                11.0
# panic_score                     NaN                                 0.0
# dep_thoughts                    NaN                                 3.0
# dep_score                       NaN                                 2.0
# comp_house                    False                               False
# alon                            2.0                                 0.0
# draw                            0.0                                 3.0
# musi                              0                                   2
# out_sum                           0                                   2
# play                              0                                   2
# read                            4.0                                 4.0
# text                            4.0                                 2.0
# tran                              0                                   0
# work                            2.0                                 2.0
# comp                          False                                True
# comp_bed_16                   False                                True
# tv                              4.0                                 3.0
# talk_mob                        2.0                                 2.0
# talk_phon                         0                                   2
#
#                        13726  13727  13728  13729             13730  \
# weight_16          59.287609    NaN    NaN    NaN               NaN
# height_16          174.36517    NaN    NaN    NaN               NaN
# comp_noint_bed_16      False  False  False  False             False
# comp_int_bed_16        False  False  False  False             False
# talk_phon_wend           NaN    NaN    NaN    NaN             False
# text_wend                NaN    NaN    NaN    NaN               1.0
# talk_mob_wend            NaN    NaN    NaN    NaN               1.0
# comp_wend                NaN    NaN    NaN    NaN               2.0
# musi_wend                NaN    NaN    NaN    NaN              True
# read_wend                NaN    NaN    NaN    NaN               1.0
# work_wend                NaN    NaN    NaN    NaN               1.0
# alon_wend                NaN    NaN    NaN    NaN               2.0
# draw_wend                NaN    NaN    NaN    NaN               1.0
# play_wend                NaN    NaN    NaN    NaN              True
# tv_wend                  NaN    NaN    NaN    NaN               3.0
# out_win_wend             NaN    NaN    NaN    NaN               2.0
# out_sum_wend             NaN    NaN    NaN    NaN              True
# tran_wend                NaN    NaN    NaN    NaN             False
# talk_phon_week           NaN    NaN    NaN    NaN             False
# text_week                NaN    NaN    NaN    NaN               1.0
# talk_mob_week            NaN    NaN    NaN    NaN               1.0
# comp_week                NaN    NaN    NaN    NaN               2.0
# musi_week                NaN    NaN    NaN    NaN              True
# read_week                NaN    NaN    NaN    NaN               1.0
# work_week                NaN    NaN    NaN    NaN               1.0
# alon_week                NaN    NaN    NaN    NaN               1.0
# draw_week                NaN    NaN    NaN    NaN               1.0
# play_week                NaN    NaN    NaN    NaN              True
# tv_week                  NaN    NaN    NaN    NaN               3.0
# out_win_week             NaN    NaN    NaN    NaN               1.0
# out_sum_week             NaN    NaN    NaN    NaN             False
# tran_week                NaN    NaN    NaN    NaN             False
# dep_band_15              0.1    NaN    NaN    NaN               NaN
# anx_band_15              3.0    NaN    NaN    NaN               NaN
# exercise                 NaN    NaN    NaN    NaN  1-4 times a week
# child_bull               NaN    NaN    NaN    NaN             False
# has_dep_diag             NaN    NaN    NaN    NaN               NaN
# secd_diag                NaN    NaN    NaN    NaN               NaN
# prim_diag                NaN    NaN    NaN    NaN               NaN
# panic_score              NaN    NaN    NaN    NaN               NaN
# dep_thoughts             NaN    NaN    NaN    NaN               NaN
# dep_score                NaN    NaN    NaN    NaN               NaN
# comp_house             False  False  False  False             False
# alon                     NaN    NaN    NaN    NaN               3.0
# draw                     NaN    NaN    NaN    NaN               2.0
# musi                     NaN    NaN    NaN    NaN                 2
# out_sum                  NaN    NaN    NaN    NaN                 1
# play                     NaN    NaN    NaN    NaN                 2
# read                     NaN    NaN    NaN    NaN               2.0
# text                     NaN    NaN    NaN    NaN               2.0
# tran                     NaN    NaN    NaN    NaN                 0
# work                     NaN    NaN    NaN    NaN               2.0
# comp                   False  False  False  False             False
# comp_bed_16            False  False  False  False             False
# tv                       NaN    NaN    NaN    NaN               6.0
# talk_mob                 NaN    NaN    NaN    NaN               2.0
# talk_phon                NaN    NaN    NaN    NaN                 0
#
#                                     13731                               13732  \
# weight_16                       58.075832                                 NaN
# height_16                      169.235565                                 NaN
# comp_noint_bed_16                   False                               False
# comp_int_bed_16                     False                               False
# talk_phon_wend                       True                                True
# text_wend                             2.0                                 2.0
# talk_mob_wend                         2.0                                 0.0
# comp_wend                             2.0                                 2.0
# musi_wend                           False                                True
# read_wend                             0.0                                 0.0
# work_wend                             0.0                                 1.0
# alon_wend                             1.0                                 1.0
# draw_wend                             1.0                                 1.0
# play_wend                            True                                True
# tv_wend                               3.0                                 1.0
# out_win_wend                          2.0                                 2.0
# out_sum_wend                         True                                True
# tran_wend                            True                               False
# talk_phon_week                       True                               False
# text_week                             2.0                                 2.0
# talk_mob_week                         2.0                                 0.0
# comp_week                             2.0                                 1.0
# musi_week                           False                                True
# read_week                             0.0                                 0.0
# work_week                             0.0                                 0.0
# alon_week                             1.0                                 0.0
# draw_week                             1.0                                 2.0
# play_week                            True                                True
# tv_week                               3.0                                 0.0
# out_win_week                          2.0                                 1.0
# out_sum_week                         True                               False
# tran_week                            True                               False
# dep_band_15                          50.0                                 NaN
# anx_band_15                          15.0                                 NaN
# exercise           5 or more times a week              5 or more times a week
# child_bull                          False                               False
# has_dep_diag                          NaN   No ICD-10 diagnosis of depression
# secd_diag                             NaN                                 0.0
# prim_diag                             NaN                                 0.0
# panic_score                           NaN                                 0.0
# dep_thoughts                          NaN                                 NaN
# dep_score                             NaN                                 0.0
# comp_house                          False                                True
# alon                                  2.0                                 1.0
# draw                                  2.0                                 3.0
# musi                                    0                                   2
# out_sum                                 2                                   1
# play                                    2                                   2
# read                                  0.0                                 0.0
# text                                  4.0                                 4.0
# tran                                    2                                   0
# work                                  0.0                                 1.0
# comp                                False                                True
# comp_bed_16                         False                               False
# tv                                    6.0                                 1.0
# talk_mob                              4.0                                 0.0
# talk_phon                               2                                   1
#
#                         13733
# weight_16           70.732913
# height_16          176.873882
# comp_noint_bed_16       False
# comp_int_bed_16         False
# talk_phon_wend            NaN
# text_wend                 NaN
# talk_mob_wend             NaN
# comp_wend                 NaN
# musi_wend                 NaN
# read_wend                 NaN
# work_wend                 NaN
# alon_wend                 NaN
# draw_wend                 NaN
# play_wend                 NaN
# tv_wend                   NaN
# out_win_wend              NaN
# out_sum_wend              NaN
# tran_wend                 NaN
# talk_phon_week            NaN
# text_week                 NaN
# talk_mob_week             NaN
# comp_week                 NaN
# musi_week                 NaN
# read_week                 NaN
# work_week                 NaN
# alon_week                 NaN
# draw_week                 NaN
# play_week                 NaN
# tv_week                   NaN
# out_win_week              NaN
# out_sum_week              NaN
# tran_week                 NaN
# dep_band_15               0.5
# anx_band_15               3.0
# exercise                  NaN
# child_bull                NaN
# has_dep_diag              NaN
# secd_diag                 NaN
# prim_diag                 NaN
# panic_score               NaN
# dep_thoughts              NaN
# dep_score                 NaN
# comp_house              False
# alon                      NaN
# draw                      NaN
# musi                      NaN
# out_sum                   NaN
# play                      NaN
# read                      NaN
# text                      NaN
# tran                      NaN
# work                      NaN
# comp                    False
# comp_bed_16             False
# tv                        NaN
# talk_mob                  NaN
# talk_phon                 NaN
#
# [57 rows x 13734 columns]

# %%
missing_data = pd.DataFrame(data[data.columns[data.isnull().any()]].isnull().sum()/len(data)*100)

# %%
names = []
for i in range(len(missing_data)):
        names.append(missing_data.iloc[i].name)
values = []
for i in range(len(missing_data)):
        values.append(missing_data.iloc[i][0])

data_1 = {'Features': names,'% Missing Data': values}

missing_df = pd.DataFrame(data_1)

missing_df.sort_values(by = ['% Missing Data'], ascending = False)
# Out:
#           Features  % Missing Data
# 38    dep_thoughts       86.857434
# 34    has_dep_diag       67.139945
# 39       dep_score       67.139945
# 37     panic_score       67.139945
# 36       prim_diag       67.139945
# 35       secd_diag       67.139945
# 43         out_sum       64.962866
# 42            musi       64.933741
# 14    out_sum_wend       64.890054
# 46            text       64.875491
# 45            read       64.868210
# 41            draw       64.853648
# 48            work       64.846367
# 50        talk_mob       64.831804
# 6        musi_wend       64.824523
# 8        work_wend       64.809961
# 44            play       64.802679
# 51       talk_phon       64.802679
# 7        read_wend       64.802679
# 4    talk_mob_wend       64.802679
# 40            alon       64.780836
# 5        comp_wend       64.766273
# 3        text_wend       64.751711
# 10       draw_wend       64.744430
# 13    out_win_wend       64.693461
# 49              tv       64.693461
# 11       play_wend       64.686180
# 9        alon_wend       64.686180
# 2   talk_phon_wend       64.686180
# 12         tv_wend       64.664337
# 47            tran       64.657055
# 15       tran_wend       64.606087
# 32        exercise       63.805155
# 33      child_bull       63.674093
# 21       read_week       63.644969
# 16  talk_phon_week       63.601281
# 20       musi_week       63.572157
# 17       text_week       63.564875
# 27    out_win_week       63.543032
# 23       alon_week       63.535751
# 19       comp_week       63.513907
# 24       draw_week       63.506626
# 22       work_week       63.506626
# 28    out_sum_week       63.492063
# 25       play_week       63.484782
# 18   talk_mob_week       63.477501
# 26         tv_week       63.448376
# 29       tran_week       63.419251
# 30     dep_band_15       61.416922
# 31     anx_band_15       61.387797
# 0        weight_16       61.038299
# 1        height_16       60.943644

# %%
## Dropping columns (features / variables) that have NaN values above a certain threshold

threshold = 50

for i in range (len(missing_df)):
  if(missing_df.iloc[i]['% Missing Data'] > threshold):
    data.drop(columns = missing_df.iloc[i][0], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13734 entries, 0 to 13733
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comp_noint_bed_16  13734 non-null  bool
#  1   comp_int_bed_16    13734 non-null  bool
#  2   comp_house         13734 non-null  bool
#  3   comp               13734 non-null  bool
#  4   comp_bed_16        13734 non-null  bool
# dtypes: bool(5)
# memory usage: 67.2 KB

# %% [markdown]
# ## Iban's stuff:

# %%
for i in range(13734):
    if data.at[i,"comp_week"] == "Not at all":
        data.at[i,"comp_week"] = 0
    if data.at[i,"comp_week"] == "Less than 1 hour":
        data.at[i,"comp_week"] = 1
    if data.at[i,"comp_week"] == "1-2 hours":
        data.at[i,"comp_week"] = 2
    if data.at[i,"comp_week"] == "3 or more hours":
        data.at[i,"comp_week"] = 3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comp_week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24488/2881982197.py in <module>
#       1 for i in range(13734):
# ----> 2     if data.at[i,"comp_week"] == "Not at all":
#       3         data.at[i,"comp_week"] = 0
#       4     if data.at[i,"comp_week"] == "Less than 1 hour":
#       5         data.at[i,"comp_week"] = 1
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2261             return self.obj.loc[key]
#    2262
# -> 2263         return super().__getitem__(key)
#    2264
#    2265     def __setitem__(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2212
#    2213         key = self._convert_key(key)
# -> 2214         return self.obj._get_value(*key, takeable=self._takeable)
#    2215
#    2216     def __setitem__(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3613             return series._values[index]
#    3614
# -> 3615         series = self._get_item_cache(col)
#    3616         engine = self.index._engine
#    3617
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_item_cache(self, item)
#    3929             #  pending resolution of GH#33047
#    3930
# -> 3931             loc = self.columns.get_loc(item)
#    3932             res = self._ixs(loc, axis=1)
#    3933
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'comp_week'

# %%
sns.set_theme()
sns.histplot(data.comp_week)

# %%
mean = np.mean(data.comp_week)
print("mean:", mean)
mode = stats.mode(data.comp_week)
print("mode:", mode)
median = np.median(data.comp_week)
print("median:", median)

# %% [markdown]
# ## Karolina's stuff:
# + type screening
# + outliers
# + black swans
# + worst cases
# + imbalanced samples

# %% [markdown]
# Outliers: https://www.analyticsvidhya.com/blog/2021/05/detecting-and-treating-outliers-treating-the-odd-one-out/
# https://statisticsbyjim.com/basics/remove-outliers/
# https://cxl.com/blog/outliers/
#
#
# A black swan is an unpredictable event that is beyond what is normally expected of a situation and has potentially severe consequences. Black swan events are characterized by their extreme rarity, severe impact, and the widespread insistence they were obvious in hindsight.

# %% [markdown]
# Imbalanced datasets: https://datascience.foundation/sciencewhitepaper/understanding-imbalanced-datasets-and-techniques-for-handling-them
# https://www.analyticsvidhya.com/blog/2021/06/5-techniques-to-handle-imbalanced-data-for-a-classification-problem/
# https://www.kdnuggets.com/2020/01/5-most-useful-techniques-handle-imbalanced-datasets.html
# https://towardsdatascience.com/handling-imbalanced-datasets-in-machine-learning-7a0e84220f28

# %% [markdown]
# Worst case analysis: https://proceedings.neurips.cc/paper/2020/hash/d34a281acc62c6bec66425f0ad6dd645-Abstract.html
# Not sure if we need it at all, probably not

# %% [markdown]
# ### Outliers

# %%
data.head()

# %%
data.to_csv("newdata.csv")
