# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import missingno as msno
from collections import Counter

# %% [markdown]
# ## Raw data:

# %%
data = pd.read_csv("./dataset/maps-synthetic-data-v1.1.csv", engine='python')
data.head()
# Out:
#    Unnamed: 0  X       flag comp_bed_9  mat_dep mat_age  weight_16  \
# 0           1  1  synthetic        NaN      3.0      30  59.294132
# 1           2  2  synthetic        NaN      9.0      26        NaN
# 2           3  3  synthetic        NaN      3.0      24        NaN
# 3           4  4  synthetic         No      NaN      22  49.812426
# 4           5  5  synthetic         No      8.0      31  62.270030
#
#     height_16     iq comp_noint_bed_16  ... dep_score comp_house tv_bed_16  \
# 0  181.602831  107.0               NaN  ...       0.0        Yes       Yes
# 1         NaN   85.0               NaN  ...       NaN        NaN       NaN
# 2         NaN    NaN               NaN  ...       NaN        NaN       NaN
# 3  160.224186    NaN               NaN  ...       NaN        NaN       NaN
# 4  191.703227  132.0               Yes  ...       NaN        NaN       NaN
#
#   creat_14 comp_games      fam_tv_eve      fam_tv_aft      fam_tv_mor     sex  \
# 0    often         No  Yes, Some Days           Other  Yes, Every Day  Female
# 1      NaN        NaN             NaN             NaN             NaN  Female
# 2      NaN        NaN  Yes, Some Days  Yes, Every Day           Other    Male
# 3      NaN         No             NaN             NaN             NaN    Male
# 4    often         No  Yes, Some Days  Yes, Every Day  Yes, Every Day  Female
#
#   birth_order
# 0           A
# 1           B
# 2           A
# 3           A
# 4           A
#
# [5 rows x 85 columns]

# %%
dictionary = pd.read_csv("./dataset/synthetic_data_dictionary.csv", engine='python')
dictionary.head()
# Out:
#   Variable Name Variable ALSPAC Name  \
# 0     agg_score                 f596
# 1     alon_week              ccs1006
# 2           NaN                  NaN
# 3
# 4
#
#                                 Variable Description Variable Type  \
# 0                    Aggression score of partnership      Discrete
# 1  Average time child spent per day doing things ...       Ordinal
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   Administered to Age of child at administration  \
# 0          Mother                  Aged 8 months
# 1           Child                Aged 198 months
# 2             NaN                            NaN
# 3             NaN                            NaN
# 4             NaN                            NaN
#
#                                       ALSPAC Measure  ALSPAC Responses  \
# 0          Derived by ALSPAC. See Processing Details               NaN
# 1  "How much time on average do you spend each da...        Not at all
# 2                                                NaN  Less than 1 hour
# 3                                                NaN         1-2 hours
# 4                                                NaN   3 or more hours
#
#                                   Processing Details Reference Document
# 0  Aggression score was determined by three quest...                NaN
# 1  The category "Not at all" was collapsed into t...                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN

# %% [markdown]
# Variables have different Age Of Child At Administration parameters. We don't need the variables with this parameter not equal to 16 (for variables related to screen time) and 18 (for variables related to a depression or anxiety diagnosis).

# %% [markdown]
# ## only the columns at 16 and 18:

# %% [markdown]
# All vars at 16 are separated into weekend and weekdays. Might be worth summing it up into total per week.

# %%
rows = dictionary[(dictionary["Age of child at administration"] == "Aged 198 months")]
rows2 = dictionary[(dictionary["Age of child at administration"] == "Aged 198 months")]
rows3 = dictionary[(dictionary["Age of child at administration"] == "Aged around 17.5 years")]
columns_to_keep_names = []
columns_to_keep_names.append(rows["Variable Name"])
columns_to_keep_names.append(rows2["Variable Name"])
columns_to_keep_names.append(rows3["Variable Name"])
print(columns_to_keep_names)
# Out:
# [1              alon_week
# 5              alon_wend
# 14            child_bull
# 20            comp_house
# 24       comp_int_bed_16
# 28     comp_noint_bed_16
# 32             comp_week
# 36             comp_wend
# 50             draw_week
# 54             draw_wend
# 59              exercise
# 89             musi_week
# 93             musi_wend
# 100         out_sum_week
# 105         out_sum_wend
# 109         out_win_week
# 113         out_win_wend
# 139            play_week
# 143            play_wend
# 148            read_week
# 152            read_wend
# 158        talk_mob_week
# 162        talk_mob_wend
# 166       talk_phon_week
# 170       talk_phon_wend
# 178            text_wend
# 182            tran_week
# 186            tran_wend
# 196              tv_week
# 200              tv_wend
# 205            work_week
# 209            work_wend
# Name: Variable Name, dtype: object, 1              alon_week
# 5              alon_wend
# 14            child_bull
# 20            comp_house
# 24       comp_int_bed_16
# 28     comp_noint_bed_16
# 32             comp_week
# 36             comp_wend
# 50             draw_week
# 54             draw_wend
# 59              exercise
# 89             musi_week
# 93             musi_wend
# 100         out_sum_week
# 105         out_sum_wend
# 109         out_win_week
# 113         out_win_wend
# 139            play_week
# 143            play_wend
# 148            read_week
# 152            read_wend
# 158        talk_mob_week
# 162        talk_mob_wend
# 166       talk_phon_week
# 170       talk_phon_wend
# 178            text_wend
# 182            tran_week
# 186            tran_wend
# 196              tv_week
# 200              tv_wend
# 205            work_week
# 209            work_wend
# Name: Variable Name, dtype: object, 48        dep_score
# 49     dep_thoughts
# 76     has_dep_diag
# 119     panic_score
# 147       prim_diag
# 156       secd_diag
# Name: Variable Name, dtype: object]

# %% [markdown]
# ## Remove vars at wrong ages:

# %%
df = pd.DataFrame(data)
columns = list(df)

for i in columns:
    if (df[i][0] in columns_to_keep_names):
        print("keep")
    else: df.drop(df[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-189695a51d37> in <module>
#       2 columns = list(df)
#       3 i = 1
# ----> 4 print((df[i][0] in columns_to_keep_names))
#       5 for i in columns:
#       6     if (df[i][0] in columns_to_keep_names):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 1

# %% [markdown]
# ## Mohammed's stuff:

# %%
for i in data.columns:
    if len(data[i].unique()) <= 7:
        print(i, data[i].unique())
# Out:
# flag ['synthetic']
# comp_bed_9 [nan 'No' 'Yes']
# comp_noint_bed_16 [nan 'Yes']
# comp_int_bed_16 [nan 'Yes']
# talk_phon_wend ['Any at all' nan 'Not at all']
# text_wend ['Less than 1 hour' nan 'Not at all' '3 or more hours' '1-2 hours']
# talk_mob_wend ['Less than 1 hour' nan 'Not at all' '1 or more hours']
# comp_wend ['1-2 hours' nan 'Less than 1 hour' '3 or more hours' 'Not at all']
# musi_wend ['Not at all' nan 'Any at all']
# read_wend ['Less than 1 hour' nan '1 or more hours' 'Not at all']
# work_wend ['3 or more hours' nan '1-2 hours' 'Less than 1 hour']
# alon_wend ['1-2 hours' nan '3 or more hours' 'Less than 1 hour']
# draw_wend ['Not at all' nan 'Less than 1 hour' '1 or more hours']
# play_wend ['3 or more hours' nan 'Less than 3 hours']
# tv_wend ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# out_win_wend ['3 or more hours' nan 'Less than 1 hour' '1-2 hours']
# out_sum_wend ['3 or more hours' nan 'Less than 3 hours']
# tran_wend ['Less than 1 hour' nan '1 or more hours']
# talk_phon_week ['Not at all' nan 'Any at all']
# text_week ['Less than 1 hour' nan 'Not at all' '3 or more hours' '1-2 hours']
# talk_mob_week ['Less than 1 hour' nan 'Not at all' '1 or more hours']
# comp_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# musi_week ['Not at all' nan 'Any at all']
# read_week ['Less than 1 hour' nan '1 or more hours' 'Not at all']
# work_week ['3 or more hours' nan '1-2 hours' 'Less than 1 hour']
# alon_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour']
# draw_week ['Not at all' nan 'Less than 1 hour' '1 or more hours']
# play_week ['3 or more hours' nan 'Less than 3 hours']
# tv_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# out_win_week ['3 or more hours' nan 'Less than 1 hour' '1-2 hours']
# out_sum_week ['3 or more hours' nan 'Less than 3 hours']
# tran_week ['Less than 1 hour' nan '1 or more hours']
# pat_pres_10 ['Yes' nan 'No']
# pat_pres_8 ['Yes' nan 'No']
# pat_pres ['Yes' nan 'No']
# mat_anx_1 ['No' nan 'Yes']
# mat_anx_18m ['No' nan 'Yes']
# mat_anx_8m ['No' nan 'Yes']
# emot_cruel ['No' nan 'Yes']
# phys_cruel ['No' nan 'Yes']
# mat_anx_0m ['No' nan 'Yes']
# pat_edu ['A level' nan 'O level' 'Vocational' 'Degree' 'cse']
# mat_edu ['A level' nan 'O level' 'Vocational' 'CSE/None' 'Degree']
# dep_band_15 ['~0.5%' nan '<0.1%' '~15%' '~50%' '>70%']
# dep_band_13 ['~0.5%' nan '<0.1%' '~15%' '~50%' '>70%']
# dep_band_10 ['~0.5%' nan '<0.1%' '~15%' '~50%' '>70%']
# dep_band_07 ['~0.5%' nan '<0.1%' '~50%' '~15%']
# anx_band_15 ['~0.5%' nan '~3%' '~15%' '~50%' '<0.1%']
# anx_band_13 ['~0.5%' nan '~15%' '~3%' '>70%' '<0.1%' '~50%']
# anx_band_10 ['~3%' nan '~0.5%' '~15%' '>70%' '~50%' '<0.1%']
# anx_band_07 ['~3%' nan '~0.5%' '~15%' '~50%' '>70%']
# exercise ['5 or more times a week' nan '1-4 times a week' '1-3 times a month'
#  'Never' 'Less than once a month']
# child_bull ['No' nan 'Yes']
# phone_14_wend [nan 'Not at all' '< 1 hour' '1 or more hours']
# phone_14_week [nan 'Not at all' '1 or more hours' '< 1 hour']
# musi_13 [nan 'No' 'Yes']
# tv_bed_9 [nan 'No' 'Yes']
# own_mob [nan 'Yes' 'No']
# has_dep_diag [' No ICD-10 diagnosis of depression' nan
#  'Yes ICD-10 diagnosis of depression']
# panic_score [ 0. nan  2.  1.  3.  4.]
# dep_thoughts [nan  1.  3.  4.  2.  5.  0.]
# dep_score [ 0. nan  2.  1.  4.  3.]
# comp_house ['Yes' nan]
# tv_bed_16 ['Yes' nan]
# creat_14 ['often' nan 'sometimes']
# comp_games ['No' nan 'Yes']
# fam_tv_eve ['Yes, Some Days' nan 'Yes, Every Day' 'Other']
# fam_tv_aft ['Other' nan 'Yes, Every Day' 'Yes, Some Days']
# fam_tv_mor ['Yes, Every Day' nan 'Other' 'Yes, Some Days']
# sex ['Female' 'Male']
# birth_order ['A' 'B']

# %%
data.drop('flag', inplace = True, axis = 1)
data.drop('Unnamed: 0', inplace = True, axis = 1)
data.drop('X', inplace = True, axis = 1)

# %%
for i in ['comp_bed_9', 'pat_pres_10', 'pat_pres_8', 'pat_pres', 'mat_anx_1', 'mat_anx_18m', 'mat_anx_8m', 'emot_cruel',
          'phys_cruel', 'mat_anx_0m', 'child_bull', 'musi_13', 'tv_bed_9', 'own_mob', 'comp_games']:
    data[i] = data[i].replace(['Yes'], True)
    data[i] = data[i].replace(['No'], False)
    
for i in ['comp_noint_bed_16', 'comp_int_bed_16', 'comp_house', 'tv_bed_16']:
    data[i] = data[i].replace(['Yes'], True)
    data[i] = data[i].fillna(False)
    
for i in ['talk_phon_wend', 'musi_wend', 'talk_phon_week', 'musi_week']:
    data[i] = data[i].replace(['Not at all'], False)
    data[i] = data[i].replace(['Any at all'], True)

for i in ['play_wend', 'out_sum_wend', 'play_week', 'out_sum_week']:
    data[i] = data[i].replace(['Less than 3 hours'], False)
    data[i] = data[i].replace(['3 or more hours'], True)
    
for i in ['tran_wend', 'tran_week']:
    data[i] = data[i].replace(['Less than 1 hour'], False)
    data[i] = data[i].replace(['1 or more hours'], True)
    
data['has_dep_diag'] = data['has_dep_diag'].replace([' No ICD-10 diagnosis of depression'], False)
data['has_dep_diag'] = data['has_dep_diag'].replace(['Yes ICD-10 diagnosis of depression'], True)

data['creat_14'] = data['creat_14'].replace(['often'], True)
data['creat_14'] = data['creat_14'].replace(['sometimes'], False)

    
data.head()
# Out:
#   comp_bed_9  mat_dep mat_age  weight_16   height_16     iq  \
# 0        NaN      3.0      30  59.294132  181.602831  107.0
# 1        NaN      9.0      26        NaN         NaN   85.0
# 2        NaN      3.0      24        NaN         NaN    NaN
# 3      False      NaN      22  49.812426  160.224186    NaN
# 4      False      8.0      31  62.270030  191.703227  132.0
#
#    comp_noint_bed_16  comp_int_bed_16 talk_phon_wend         text_wend  ...  \
# 0              False            False           True  Less than 1 hour  ...
# 1              False            False            NaN               NaN  ...
# 2              False            False            NaN               NaN  ...
# 3              False            False            NaN               NaN  ...
# 4               True            False          False        Not at all  ...
#
#   dep_score comp_house tv_bed_16 creat_14 comp_games      fam_tv_eve  \
# 0       0.0       True      True     True      False  Yes, Some Days
# 1       NaN      False     False      NaN        NaN             NaN
# 2       NaN      False     False      NaN        NaN  Yes, Some Days
# 3       NaN      False     False      NaN      False             NaN
# 4       NaN      False     False     True      False  Yes, Some Days
#
#        fam_tv_aft      fam_tv_mor     sex birth_order
# 0           Other  Yes, Every Day  Female           A
# 1             NaN             NaN  Female           B
# 2  Yes, Every Day           Other    Male           A
# 3             NaN             NaN    Male           A
# 4  Yes, Every Day  Yes, Every Day  Female           A
#
# [5 rows x 82 columns]

# %%
for i in data.columns:
    if len(data[i].unique()) == 4:
        print(i, data[i].unique())
# Out:
# talk_mob_wend ['Less than 1 hour' nan 'Not at all' '1 or more hours']
# read_wend ['Less than 1 hour' nan '1 or more hours' 'Not at all']
# work_wend ['3 or more hours' nan '1-2 hours' 'Less than 1 hour']
# alon_wend ['1-2 hours' nan '3 or more hours' 'Less than 1 hour']
# draw_wend ['Not at all' nan 'Less than 1 hour' '1 or more hours']
# out_win_wend ['3 or more hours' nan 'Less than 1 hour' '1-2 hours']
# talk_mob_week ['Less than 1 hour' nan 'Not at all' '1 or more hours']
# read_week ['Less than 1 hour' nan '1 or more hours' 'Not at all']
# work_week ['3 or more hours' nan '1-2 hours' 'Less than 1 hour']
# alon_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour']
# draw_week ['Not at all' nan 'Less than 1 hour' '1 or more hours']
# out_win_week ['3 or more hours' nan 'Less than 1 hour' '1-2 hours']
# phone_14_wend [nan 'Not at all' '< 1 hour' '1 or more hours']
# phone_14_week [nan 'Not at all' '1 or more hours' '< 1 hour']
# fam_tv_eve ['Yes, Some Days' nan 'Yes, Every Day' 'Other']
# fam_tv_aft ['Other' nan 'Yes, Every Day' 'Yes, Some Days']
# fam_tv_mor ['Yes, Every Day' nan 'Other' 'Yes, Some Days']

# %%
   
for i in ['talk_mob_wend', 'read_wend', 'draw_wend', 'talk_mob_week', 'read_week', 'draw_week']:
    data[i] = data[i].replace(['Not at all'], 0)
    data[i] = data[i].replace(['Less than 1 hour'], 1)
    data[i] = data[i].replace(['1 or more hours'], 2)
    
for i in ['work_wend', 'alon_wend', 'out_win_wend', 'work_week', 'alon_week', 'out_win_week']:
    data[i] = data[i].replace(['Less than 1 hour'], 0)
    data[i] = data[i].replace(['1-2 hours'], 1)
    data[i] = data[i].replace(['3 or more hours'], 2)
    
for i in ['phone_14_wend', 'phone_14_week']:
    data[i] = data[i].replace(['Not at all'], 0)
    data[i] = data[i].replace(['< 1 hour'], 1)
    data[i] = data[i].replace(['1 or more hours'], 2)
    
for i in ['fam_tv_eve', 'fam_tv_aft', 'fam_tv_mor']:
    data[i] = data[i].replace(['Other'], 0)
    data[i] = data[i].replace(['Yes, Some Days'], 1)
    data[i] = data[i].replace(['Yes, Every Day'], 2)

# %%
for i in data.columns:
    if len(data[i].unique()) == 4:
        print(i, data[i].unique())
# Out:
# talk_mob_wend [ 1. nan  0.  2.]
# read_wend [ 1. nan  2.  0.]
# work_wend [ 2. nan  1.  0.]
# alon_wend [ 1. nan  2.  0.]
# draw_wend [ 0. nan  1.  2.]
# out_win_wend [ 2. nan  0.  1.]
# talk_mob_week [ 1. nan  0.  2.]
# read_week [ 1. nan  2.  0.]
# work_week [ 2. nan  1.  0.]
# alon_week [ 1. nan  2.  0.]
# draw_week [ 0. nan  1.  2.]
# out_win_week [ 2. nan  0.  1.]
# phone_14_wend [nan  0.  1.  2.]
# phone_14_week [nan  0.  2.  1.]
# fam_tv_eve [ 1. nan  2.  0.]
# fam_tv_aft [ 0. nan  2.  1.]
# fam_tv_mor [ 2. nan  0.  1.]

# %%
for i in data.columns:
    if len(data[i].unique()) == 5:
        print(i, data[i].unique())
# Out:
# text_wend ['Less than 1 hour' nan 'Not at all' '3 or more hours' '1-2 hours']
# comp_wend ['1-2 hours' nan 'Less than 1 hour' '3 or more hours' 'Not at all']
# tv_wend ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# text_week ['Less than 1 hour' nan 'Not at all' '3 or more hours' '1-2 hours']
# comp_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# tv_week ['1-2 hours' nan '3 or more hours' 'Less than 1 hour' 'Not at all']
# dep_band_07 ['~0.5%' nan '<0.1%' '~50%' '~15%']

# %%
for i in ['text_wend', 'comp_wend', 'tv_wend', 'text_week', 'comp_week', 'tv_week']:
    data[i] = data[i].replace(['Not at all'], 0)
    data[i] = data[i].replace(['Less than 1 hour'], 1)
    data[i] = data[i].replace(['1-2 hours'], 2)
    data[i] = data[i].replace(['3 or more hours'], 3)

# %%
for i in data.columns:
    if len(data[i].unique()) == 5:
        print(i, data[i].unique())
# Out:
# text_wend [ 1. nan  0.  3.  2.]
# comp_wend [ 2. nan  1.  3.  0.]
# tv_wend [ 2. nan  3.  1.  0.]
# text_week [ 1. nan  0.  3.  2.]
# comp_week [ 2. nan  3.  1.  0.]
# tv_week [ 2. nan  3.  1.  0.]
# dep_band_07 ['~0.5%' nan '<0.1%' '~50%' '~15%']

# %%
percentages = ['dep_band_07', 'dep_band_15', 'dep_band_13', 'dep_band_10', 'anx_band_15', 'anx_band_07']
for i in percentages:
    data[i] = data[i].str.strip('%<>~')

# %%
for i in percentages:
    print(i, data[i].unique())
# Out:
# dep_band_07 ['0.5' nan '0.1' '50' '15']
# dep_band_15 ['0.5' nan '0.1' '15' '50' '70']
# dep_band_13 ['0.5' nan '0.1' '15' '50' '70']
# dep_band_10 ['0.5' nan '0.1' '15' '50' '70']
# anx_band_15 ['0.5' nan '3' '15' '50' '0.1']
# anx_band_07 ['3' nan '0.5' '15' '50' '70']

# %%
data['exercise'] = data['exercise'].replace(['Never', 'Less than once a month', '1-3 times a month',
                                             '1-4 times a week', '5 or more times a week'], range(5))

print(data['exercise'].unique())
# Out:
# [ 4. nan  3.  2.  0.  1.]

# %% [markdown]
# ## Mohamed's stuff

# %%
transposed_data = data.T
transposed_data
# Out:
#                0       1     2        3        4        5     6        7      \
# comp_bed_9       NaN     NaN   NaN    False    False    False   NaN      NaN
# mat_dep            3       9     3      NaN        8       10     0      NaN
# mat_age           30      26    24       22       31       30    36       26
# weight_16    59.2941     NaN   NaN  49.8124    62.27  78.9366   NaN  84.2997
# height_16    181.603     NaN   NaN  160.224  191.703  169.722   NaN  186.327
# ...              ...     ...   ...      ...      ...      ...   ...      ...
# fam_tv_eve         1     NaN     1      NaN        1        1     2        2
# fam_tv_aft         0     NaN     2      NaN        2        0     2        2
# fam_tv_mor         2     NaN     0      NaN        2        1     0        2
# sex           Female  Female  Male     Male   Female   Female  Male   Female
# birth_order        A       B     A        A        A        A     A        A
#
#                8        9      ...  13724  13725    13726 13727   13728  \
# comp_bed_9     False      NaN  ...  False  False    False   NaN    True
# mat_dep            4        0  ...      3      1      NaN     0       8
# mat_age           30       30  ...     33     32       18    22      21
# weight_16    70.6573  70.5294  ...    NaN    NaN  59.2876   NaN     NaN
# height_16    176.028  187.778  ...    NaN    NaN  174.365   NaN     NaN
# ...              ...      ...  ...    ...    ...      ...   ...     ...
# fam_tv_eve       NaN        1  ...      1      1        1     1       1
# fam_tv_aft         2        0  ...      0      0        2     2       2
# fam_tv_mor         2        0  ...      0      0        2     1       0
# sex             Male   Female  ...   Male   Male   Female  Male  Female
# birth_order        A        A  ...      A      A        A     A       A
#
#               13729  13730    13731  13732    13733
# comp_bed_9      NaN  False      NaN  False    False
# mat_dep          13      6       21     10        6
# mat_age          27     29       37     30       26
# weight_16       NaN    NaN  58.0758    NaN  70.7329
# height_16       NaN    NaN  169.236    NaN  176.874
# ...             ...    ...      ...    ...      ...
# fam_tv_eve        2      2        0      1        1
# fam_tv_aft        2      0        0      0        0
# fam_tv_mor        2      0        0      2        2
# sex          Female   Male     Male   Male     Male
# birth_order       A      A        A      A        A
#
# [82 rows x 13734 columns]

# %%
missing_data = pd.DataFrame(data[data.columns[data.isnull().any()]].isnull().sum()/len(data)*100)

# %%
names = []
for i in range(len(missing_data)):
        names.append(missing_data.iloc[i].name)
values = []
for i in range(len(missing_data)):
        values.append(missing_data.iloc[i][0])

data_1 = {'Features': names,'% Missing Data': values}

missing_df = pd.DataFrame(data_1)

missing_df.sort_values(by = ['% Missing Data'], ascending = False)
# Out:
#         Features  % Missing Data
# 69  dep_thoughts       86.857434
# 64       own_mob       68.064657
# 68   panic_score       67.139945
# 65  has_dep_diag       67.139945
# 66     secd_diag       67.139945
# ..           ...             ...
# 43    phys_cruel       17.715159
# 42    emot_cruel       17.715159
# 48       mat_edu        9.895151
# 49        parity        8.664628
# 2        mat_age        2.970730
#
# [76 rows x 2 columns]

# %%
## Dropping columns (features / variables) that have NaN values above a certain threshold

threshold = 50

for i in range (len(missing_df)):
  if(missing_df.iloc[i]['% Missing Data'] > threshold):
    data.drop(columns = missing_df.iloc[i][0], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13734 entries, 0 to 13733
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comp_bed_9         8174 non-null   object
#  1   mat_dep            11145 non-null  float64
#  2   mat_age            13326 non-null  object
#  3   iq                 7288 non-null   float64
#  4   comp_noint_bed_16  13734 non-null  bool
#  5   comp_int_bed_16    13734 non-null  bool
#  6   pat_pres_10        8057 non-null   object
#  7   pat_pres_8         7729 non-null   object
#  8   pat_pres           9579 non-null   object
#  9   num_home           9583 non-null   object
#  10  mat_anx_1          9700 non-null   object
#  11  mat_anx_18m        9884 non-null   object
#  12  mat_anx_8m         10488 non-null  object
#  13  agg_score          10714 non-null  float64
#  14  emot_cruel         11301 non-null  object
#  15  phys_cruel         11301 non-null  object
#  16  mat_anx_0m         11265 non-null  object
#  17  pat_ses            11021 non-null  object
#  18  mat_ses            10110 non-null  object
#  19  pat_edu            10750 non-null  object
#  20  mat_edu            12375 non-null  object
#  21  parity             12544 non-null  float64
#  22  dep_band_13        7003 non-null   object
#  23  dep_band_10        7679 non-null   object
#  24  dep_band_07        8089 non-null   object
#  25  anx_band_13        7158 non-null   object
#  26  anx_band_10        7852 non-null   object
#  27  anx_band_07        8280 non-null   object
#  28  musi_13            6880 non-null   object
#  29  tv_bed_9           8348 non-null   object
#  30  comp_house         13734 non-null  bool
#  31  tv_bed_16          13734 non-null  bool
#  32  creat_14           7093 non-null   object
#  33  comp_games         9660 non-null   object
#  34  fam_tv_eve         11174 non-null  float64
#  35  fam_tv_aft         11038 non-null  float64
#  36  fam_tv_mor         11096 non-null  float64
#  37  sex                13734 non-null  object
#  38  birth_order        13734 non-null  object
# dtypes: bool(4), float64(7), object(28)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Iban's stuff:

# %%
for i in range(13734):
    if data.at[i,"comp_week"] == "Not at all":
        data.at[i,"comp_week"] = 0
    if data.at[i,"comp_week"] == "Less than 1 hour":
        data.at[i,"comp_week"] = 1
    if data.at[i,"comp_week"] == "1-2 hours":
        data.at[i,"comp_week"] = 2
    if data.at[i,"comp_week"] == "3 or more hours":
        data.at[i,"comp_week"] = 3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comp_week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-74d76509d723> in <module>
#       1 for i in range(13734):
# ----> 2     if data.at[i,"comp_week"] == "Not at all":
#       3         data.at[i,"comp_week"] = 0
#       4     if data.at[i,"comp_week"] == "Less than 1 hour":
#       5         data.at[i,"comp_week"] = 1
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2078             return self.obj.loc[key]
#    2079
# -> 2080         return super().__getitem__(key)
#    2081
#    2082     def __setitem__(self, key, value):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2025
#    2026         key = self._convert_key(key)
# -> 2027         return self.obj._get_value(*key, takeable=self._takeable)
#    2028
#    2029     def __setitem__(self, key, value):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3004             return series._values[index]
#    3005
# -> 3006         series = self._get_item_cache(col)
#    3007         engine = self.index._engine
#    3008
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3538             #  pending resolution of GH#33047
#    3539
# -> 3540             loc = self.columns.get_loc(item)
#    3541             values = self._mgr.iget(loc)
#    3542             res = self._box_col_values(values, loc)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'comp_week'

# %%
sns.set_theme()
sns.histplot(data.comp_week)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c5056328ea7c> in <module>
#       1 sns.set_theme()
# ----> 2 sns.histplot(data.comp_week)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'comp_week'

# %%
mean = np.mean(data.comp_week)
print("mean:", mean)
mode = stats.mode(data.comp_week)
print("mode:", mode)
median = np.median(data.comp_week)
print("median:", median)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-713fbc6a70fc> in <module>
# ----> 1 mean = np.mean(data.comp_week)
#       2 print("mean:", mean)
#       3 mode = stats.mode(data.comp_week)
#       4 print("mode:", mode)
#       5 median = np.median(data.comp_week)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'comp_week'

# %% [markdown]
# ## Karolina's stuff:
# + type screening
# + outliers
# + black swans
# + worst cases
# + imbalanced samples

# %% [markdown]
# Outliers: https://www.analyticsvidhya.com/blog/2021/05/detecting-and-treating-outliers-treating-the-odd-one-out/
# https://statisticsbyjim.com/basics/remove-outliers/
# https://cxl.com/blog/outliers/
#
#
# A black swan is an unpredictable event that is beyond what is normally expected of a situation and has potentially severe consequences. Black swan events are characterized by their extreme rarity, severe impact, and the widespread insistence they were obvious in hindsight.

# %% [markdown]
# Imbalanced datasets: https://datascience.foundation/sciencewhitepaper/understanding-imbalanced-datasets-and-techniques-for-handling-them
# https://www.analyticsvidhya.com/blog/2021/06/5-techniques-to-handle-imbalanced-data-for-a-classification-problem/
# https://www.kdnuggets.com/2020/01/5-most-useful-techniques-handle-imbalanced-datasets.html
# https://towardsdatascience.com/handling-imbalanced-datasets-in-machine-learning-7a0e84220f28

# %% [markdown]
# Worst case analysis: https://proceedings.neurips.cc/paper/2020/hash/d34a281acc62c6bec66425f0ad6dd645-Abstract.html
# Not sure if we need it at all, probably not

# %% [markdown]
# ### Outliers

# %%
data.head()
# Out:
#   comp_bed_9  mat_dep mat_age     iq  comp_noint_bed_16  comp_int_bed_16  \
# 0        NaN      3.0      30  107.0              False            False
# 1        NaN      9.0      26   85.0              False            False
# 2        NaN      3.0      24    NaN              False            False
# 3      False      NaN      22    NaN              False            False
# 4      False      8.0      31  132.0               True            False
#
#   pat_pres_10 pat_pres_8 pat_pres num_home  ... tv_bed_9 comp_house tv_bed_16  \
# 0        True       True     True        4  ...      NaN       True      True
# 1         NaN        NaN      NaN      NaN  ...      NaN      False     False
# 2         NaN        NaN      NaN      NaN  ...      NaN      False     False
# 3         NaN       True      NaN      NaN  ...    False      False     False
# 4         NaN        NaN    False        4  ...     True      False     False
#
#    creat_14 comp_games fam_tv_eve fam_tv_aft fam_tv_mor     sex birth_order
# 0      True      False        1.0        0.0        2.0  Female           A
# 1       NaN        NaN        NaN        NaN        NaN  Female           B
# 2       NaN        NaN        1.0        2.0        0.0    Male           A
# 3       NaN      False        NaN        NaN        NaN    Male           A
# 4      True      False        1.0        2.0        2.0  Female           A
#
# [5 rows x 39 columns]
